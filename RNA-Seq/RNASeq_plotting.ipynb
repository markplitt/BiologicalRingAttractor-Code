# %% [markdown]
# #### Load packages and functions

# %%
import matplotlib.pyplot as plt
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib import rcParams, colors
import numpy as np
import pickle

def getSubDat(cellsMeta, cellsCount, name, norm):
    sampIds = cellsMeta[[name in samp for samp in cellsMeta["sample"].values]].reset_index()
    getDat = cellsCount[[samp for samp in sampIds["qp_well_fq"]]].copy()
    getDat['gene_id'] = cellsCount['gene_id']
    getDat = getDat.set_index('gene_id')
    if norm == 1:
        for i in range(0,len(getDat.columns)):
            getDat.iloc[:,i] = getDat.iloc[:,i]*(1E6/getDat.iloc[:,i].sum())
    getDat.columns = [sampName + '-' + sampIds["qp_well_fq"][i] for i,sampName in enumerate(sampIds["sample"])] 
    getDat = getDat.sort_index()
    return getDat

# %% [markdown]
# ## Load gene info

# %%
glia = pd.read_csv('./geneIDs/glia.csv')

transmitters = pd.read_csv('./geneIDs/transmitters.csv')
receptors = pd.read_csv('./geneIDs/receptors.csv')

VgatedChannels = pd.read_csv('./geneIDs/VgatedChannels.csv')
innexins = pd.read_csv('./geneIDs/innexins.csv')

neuropeptides = pd.read_csv('./geneIDs/neuropeptides.csv')
GPCRs = pd.read_csv('./geneIDs/GPCRs.csv')

NOreceptors = pd.read_csv('./geneIDs/NOreceptors.csv')

retrotransmitters = pd.read_csv('./geneIDs/retrotransmitters.csv')

# %% [markdown]
# ## Load RNA Seq data

# %% [markdown]
# ### Load the bulk data

# %%
# Load the counts and key
bulkDat1 = pd.read_csv('./data/180914_NB551104_0096_AHCCTVAFXY_consolidated.FPKM.genes.updated.txt',delimiter='\t')
bulkDat2 = pd.read_csv('./data/181114_NB551104_0107_AHCFK2BGX9_consolidated.FPKM.genes.updated.txt',delimiter='\t')
bulkDat3 = pd.read_csv('./data/181121_NB551104_0109_AHF2CMAFXY_consolidated.FPKM.genes.updated.txt',delimiter='\t')
bulkDat4 = pd.read_csv('./data/171116_NB551104_0039_AHWYH3BGX3_consolidated.FPKM.genes.updated.txt',delimiter='\t')

bulkDat_All = pd.concat([bulkDat1, bulkDat2.iloc[:,3:], bulkDat3.iloc[:,3:], bulkDat4.iloc[:,3:]], axis = 1).set_index('gene_id')

bulkKey = pd.read_csv('./data/all_sample_key.txt',delimiter='\t',header=None)
bulkKey.columns = ['sample','line']

# Specify the order to lines to look at
lines = ['SS00096', 'SS00131', 'SS02191', 'SS02238', 'SS30295','SS02232','SS02233','5ng_flybrain']

# Load the bulk cell dat for each line
bulkSeq = pd.DataFrame()
for ln in lines:
    sampNames = [bulkKey['sample'][i] for i, val in enumerate(bulkKey['line']) if ln in val]
    datNow = bulkDat_All[sampNames]
    datNow.columns = [nm for nm in bulkKey['line'] if ln in nm]
    bulkSeq = pd.concat([bulkSeq,datNow],axis=1)
bulkSeq.columns = ['E-PG_l1r1','E-PG_l1r2','E-PG_l2r1','E-PG_l2r2',
                   'P-EG_r1','P-EG_r2',
                   'D7_l1r1','D7_l1r2','D7_l2r1','D7_l2r2',
                   'P-EN2_l1r1','P-EN2_l2r1',
                   'wholebrain_1', 'wholebrain_2']

# Save the data as a csv file to load into the R script
bulkSeq.to_csv('./data/bulkSeq.csv', sep=',')

# %% [markdown]
# ### Load the low cell and single cell data

# %%
cellsMeta = pd.read_csv('./data/merged_sample_info.txt',delimiter='\t')
cellsCount = pd.read_csv('./data/merged_counts.txt',delimiter='\t')

# %% [markdown]
# ### Get the low cell data

# %%
PEN2s_lowCell = getSubDat(cellsMeta, cellsCount,"SS02232_35c",1)
R4ds_lowCell = getSubDat(cellsMeta, cellsCount,"SS00238",1)
wholeBrain_lowCell = getSubDat(cellsMeta, cellsCount,"50pg_CBqRNA",1)

# Combine the low cell data into one dataframe
lowCellSeq = pd.concat([PEN2s_lowCell,R4ds_lowCell,wholeBrain_lowCell], axis=1, join='inner')
lowCellSeq.columns = ['P-EN2_r1','P-EN2_r2','P-EN2_r3','P-EN2_r4','P-EN2_r5','P-EN2_r6','P-EN2_r7',
                      'P-EN2_r8','P-EN2_r9','P-EN2_r10','P-EN2_r11','P-EN2_r12','P-EN2_r13','P-EN2_r14',
                      'ring_r1','ring_r2','ring_r3','ring_r4','ring_r5','ring_r6','ring_r7',
                      'wholebrain_r1','wholebrain_r2','wholebrain_r3','wholebrain_r4',
                      'wholebrain_r5','wholebrain_r6','wholebrain_r7','wholebrain_r8']
lowCellSeqMean = pd.concat([PEN2s_lowCell.mean(axis=1), R4ds_lowCell.mean(axis=1), wholeBrain_lowCell.mean(axis=1)],
                           axis = 1, join = 'inner').rename(columns={0: "P-EN2", 1: "R4d", 2: "wholeBrain"})

# Save the data as a csv file to load into the R script
lowCellSeq.to_csv('./data/lowCellSeq.csv', sep=',')
# Out:
# /var/folders/kf/mfw6jp8n1j9596qy__gdvty00000gn/T/ipykernel_70607/3816208988.py:15: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value 'gene_id
# FBgn0267594        0.000000
# FBgn0259849        0.000000
# FBgn0085494        0.000000
# FBgn0085506        0.000000
# FBgn0259870        0.000000
#                    ...
# LexA-p65           0.000000
# mCD8-GFP           0.000000
# myr-GFP-p10     4056.997553
# nls-tdTomato    1775.176318
# unc84-2xEGFP       0.000000
# Name: Q5_A01_Sample_3_Q5_01_pool, Length: 17713, dtype: float64' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   getDat.iloc[:,i] = getDat.iloc[:,i]*(1E6/getDat.iloc[:,i].sum())
# /var/folders/kf/mfw6jp8n1j9596qy__gdvty00000gn/T/ipykernel_70607/3816208988.py:15: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value 'gene_id
# FBgn0267594        0.000000
# FBgn0259849        0.000000
# FBgn0085494        0.000000
# FBgn0085506        0.000000
# FBgn0259870        0.000000
#                    ...
# LexA-p65           0.000000
# mCD8-GFP           0.000000
# myr-GFP-p10     3803.940366
# nls-tdTomato    1501.501502
# unc84-2xEGFP       0.000000
# Name: Q5_B01_Sample_3_Q5_01_pool, Length: 17713, dtype: float64' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   getDat.iloc[:,i] = getDat.iloc[:,i]*(1E6/getDat.iloc[:,i].sum())
# /var/folders/kf/mfw6jp8n1j9596qy__gdvty00000gn/T/ipykernel_70607/3816208988.py:15: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value 'gene_id
# FBgn0267594        0.000000
# FBgn0259849        0.000000
# FBgn0085494        0.000000
# FBgn0085506        0.000000
# FBgn0259870        0.000000
#                    ...
# LexA-p65           0.000000
# mCD8-GFP           0.000000
# myr-GFP-p10     4786.191623
# nls-tdTomato    3428.030728
# unc84-2xEGFP       0.000000
# Name: Q5_C01_Sample_3_Q5_01_pool, Length: 17713, dtype: float64' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   getDat.iloc[:,i] = getDat.iloc[:,i]*(1E6/getDat.iloc[:,i].sum())
# /var/folders/kf/mfw6jp8n1j9596qy__gdvty00000gn/T/ipykernel_70607/3816208988.py:15: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value 'gene_id
# FBgn0267594        0.000000
# FBgn0259849        0.000000
# FBgn0085494        0.000000
# FBgn0085506        0.000000
# FBgn0259870        0.000000
#                    ...
# LexA-p65           0.000000
# mCD8-GFP           0.000000
# myr-GFP-p10     3649.768536
# nls-tdTomato    3202.692212
# unc84-2xEGFP       2.032165
# Name: Q5_D01_Sample_3_Q5_01_pool, Length: 17713, dtype: float64' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   getDat.iloc[:,i] = getDat.iloc[:,i]*(1E6/getDat.iloc[:,i].sum())
# /var/folders/kf/mfw6jp8n1j9596qy__gdvty00000gn/T/ipykernel_70607/3816208988.py:15: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value 'gene_id
# FBgn0267594        0.000000
# FBgn0259849        0.000000
# FBgn0085494        0.000000
# FBgn0085506        0.000000
# FBgn0259870        0.000000
#                    ...
# LexA-p65           0.000000
# mCD8-GFP           0.000000
# myr-GFP-p10     4862.532374
# nls-tdTomato    3185.010544
# unc84-2xEGFP       0.000000
# Name: Q5_E01_Sample_3_Q5_01_pool, Length: 17713, dtype: float64' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   getDat.iloc[:,i] = getDat.iloc[:,i]*(1E6/getDat.iloc[:,i].sum())
# /var/folders/kf/mfw6jp8n1j9596qy__gdvty00000gn/T/ipykernel_70607/3816208988.py:15: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value 'gene_id
# FBgn0267594        0.000000
# FBgn0259849        0.000000
# FBgn0085494        0.000000
# FBgn0085506        0.000000
# FBgn0259870        0.000000
#                    ...
# LexA-p65           0.000000
# mCD8-GFP           0.000000
# myr-GFP-p10     4695.138126
# nls-tdTomato    3482.511653
# unc84-2xEGFP       0.000000
# Name: Q5_F01_Sample_3_Q5_01_pool, Length: 17713, dtype: float64' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   getDat.iloc[:,i] = getDat.iloc[:,i]*(1E6/getDat.iloc[:,i].sum())
# /var/folders/kf/mfw6jp8n1j9596qy__gdvty00000gn/T/ipykernel_70607/3816208988.py:15: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value 'gene_id
# FBgn0267594        0.000000
# FBgn0259849        0.000000
# FBgn0085494        0.000000
# FBgn0085506        0.000000
# FBgn0259870        0.000000
#                    ...
# LexA-p65           0.000000
# mCD8-GFP           0.000000
# myr-GFP-p10     4624.832864
# nls-tdTomato    1794.365692
# unc84-2xEGFP       0.000000
# Name: Q5_G01_Sample_3_Q5_01_pool, Length: 17713, dtype: float64' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   getDat.iloc[:,i] = getDat.iloc[:,i]*(1E6/getDat.iloc[:,i].sum())
# /var/folders/kf/mfw6jp8n1j9596qy__gdvty00000gn/T/ipykernel_70607/3816208988.py:15: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value 'gene_id
# FBgn0267594        0.000000
# FBgn0259849        0.000000
# FBgn0085494        0.000000
# FBgn0085506        0.000000
# FBgn0259870        0.000000
#                    ...
# LexA-p65           0.000000
# mCD8-GFP           0.000000
# myr-GFP-p10     2372.351850
# nls-tdTomato    3883.627843
# unc84-2xEGFP       0.000000
# Name: Q5_H01_Sample_3_Q5_01_pool, Length: 17713, dtype: float64' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   getDat.iloc[:,i] = getDat.iloc[:,i]*(1E6/getDat.iloc[:,i].sum())
# /var/folders/kf/mfw6jp8n1j9596qy__gdvty00000gn/T/ipykernel_70607/3816208988.py:15: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value 'gene_id
# FBgn0267594        0.000000
# FBgn0259849        0.000000
# FBgn0085494        0.000000
# FBgn0085506        0.000000
# FBgn0259870        0.000000
#                    ...
# LexA-p65           0.000000
# mCD8-GFP           0.000000
# myr-GFP-p10     4881.929285
# nls-tdTomato    4155.085304
# unc84-2xEGFP       0.000000
# Name: Q5_A02_Sample_3_Q5_02_pool, Length: 17713, dtype: float64' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   getDat.iloc[:,i] = getDat.iloc[:,i]*(1E6/getDat.iloc[:,i].sum())
# /var/folders/kf/mfw6jp8n1j9596qy__gdvty00000gn/T/ipykernel_70607/3816208988.py:15: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value 'gene_id
# FBgn0267594        0.000000
# FBgn0259849        0.000000
# FBgn0085494        0.000000
# FBgn0085506        0.000000
# FBgn0259870        0.000000
#                    ...
# LexA-p65           0.000000
# mCD8-GFP           0.000000
# myr-GFP-p10     6587.078225
# nls-tdTomato    1760.601553
# unc84-2xEGFP       0.000000
# Name: Q5_B02_Sample_3_Q5_02_pool, Length: 17713, dtype: float64' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   getDat.iloc[:,i] = getDat.iloc[:,i]*(1E6/getDat.iloc[:,i].sum())
# /var/folders/kf/mfw6jp8n1j9596qy__gdvty00000gn/T/ipykernel_70607/3816208988.py:15: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value 'gene_id
# FBgn0267594        0.000000
# FBgn0259849        0.000000
# FBgn0085494        0.000000
# FBgn0085506        0.000000
# FBgn0259870        0.000000
#                    ...
# LexA-p65           0.000000
# mCD8-GFP           2.191440
# myr-GFP-p10     6935.906960
# nls-tdTomato    2357.989222
# unc84-2xEGFP       0.000000
# Name: Q5_C02_Sample_3_Q5_02_pool, Length: 17713, dtype: float64' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   getDat.iloc[:,i] = getDat.iloc[:,i]*(1E6/getDat.iloc[:,i].sum())
# /var/folders/kf/mfw6jp8n1j9596qy__gdvty00000gn/T/ipykernel_70607/3816208988.py:15: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value 'gene_id
# FBgn0267594        0.000000
# FBgn0259849        0.000000
# FBgn0085494        0.000000
# FBgn0085506        0.000000
# FBgn0259870        0.000000
#                    ...
# LexA-p65           0.000000
# mCD8-GFP           0.000000
# myr-GFP-p10     5106.498067
# nls-tdTomato    4874.677222
# unc84-2xEGFP       0.000000
# Name: Q5_D02_Sample_3_Q5_02_pool, Length: 17713, dtype: float64' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   getDat.iloc[:,i] = getDat.iloc[:,i]*(1E6/getDat.iloc[:,i].sum())
# /var/folders/kf/mfw6jp8n1j9596qy__gdvty00000gn/T/ipykernel_70607/3816208988.py:15: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value 'gene_id
# FBgn0267594        0.000000
# FBgn0259849        0.000000
# FBgn0085494        0.000000
# FBgn0085506        0.000000
# FBgn0259870        0.000000
#                    ...
# LexA-p65           0.000000
# mCD8-GFP           0.000000
# myr-GFP-p10     3524.589818
# nls-tdTomato     673.259971
# unc84-2xEGFP       0.000000
# Name: Q5_E02_Sample_3_Q5_02_pool, Length: 17713, dtype: float64' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   getDat.iloc[:,i] = getDat.iloc[:,i]*(1E6/getDat.iloc[:,i].sum())
# /var/folders/kf/mfw6jp8n1j9596qy__gdvty00000gn/T/ipykernel_70607/3816208988.py:15: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value 'gene_id
# FBgn0267594         0.000000
# FBgn0259849         0.000000
# FBgn0085494         0.000000
# FBgn0085506         0.000000
# FBgn0259870         0.000000
#                     ...
# LexA-p65            0.000000
# mCD8-GFP            0.000000
# myr-GFP-p10     10279.090432
# nls-tdTomato     2376.240290
# unc84-2xEGFP        0.000000
# Name: Q5_F02_Sample_3_Q5_02_pool, Length: 17713, dtype: float64' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   getDat.iloc[:,i] = getDat.iloc[:,i]*(1E6/getDat.iloc[:,i].sum())
# /var/folders/kf/mfw6jp8n1j9596qy__gdvty00000gn/T/ipykernel_70607/3816208988.py:15: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value 'gene_id
# FBgn0267594        0.000000
# FBgn0259849        0.000000
# FBgn0085494        0.000000
# FBgn0085506        0.000000
# FBgn0259870        0.000000
#                    ...
# LexA-p65           0.000000
# mCD8-GFP           0.000000
# myr-GFP-p10     9071.846683
# nls-tdTomato    6473.272621
# unc84-2xEGFP       0.000000
# Name: Q6_A04_Sample_Q6_Pool_01, Length: 17713, dtype: float64' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   getDat.iloc[:,i] = getDat.iloc[:,i]*(1E6/getDat.iloc[:,i].sum())
# /var/folders/kf/mfw6jp8n1j9596qy__gdvty00000gn/T/ipykernel_70607/3816208988.py:15: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value 'gene_id
# FBgn0267594         0.000000
# FBgn0259849         0.000000
# FBgn0085494         0.000000
# FBgn0085506         0.000000
# FBgn0259870         0.000000
#                     ...
# LexA-p65            0.000000
# mCD8-GFP            0.000000
# myr-GFP-p10     10896.717216
# nls-tdTomato     6916.393533
# unc84-2xEGFP        0.000000
# Name: Q6_B04_Sample_Q6_Pool_01, Length: 17713, dtype: float64' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   getDat.iloc[:,i] = getDat.iloc[:,i]*(1E6/getDat.iloc[:,i].sum())
# /var/folders/kf/mfw6jp8n1j9596qy__gdvty00000gn/T/ipykernel_70607/3816208988.py:15: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value 'gene_id
# FBgn0267594        0.000000
# FBgn0259849        0.000000
# FBgn0085494        0.000000
# FBgn0085506        0.000000
# FBgn0259870        0.000000
#                    ...
# LexA-p65           0.000000
# mCD8-GFP           0.000000
# myr-GFP-p10     7485.349212
# nls-tdTomato    6686.987458
# unc84-2xEGFP       0.000000
# Name: Q6_C04_Sample_Q6_Pool_01, Length: 17713, dtype: float64' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   getDat.iloc[:,i] = getDat.iloc[:,i]*(1E6/getDat.iloc[:,i].sum())
# /var/folders/kf/mfw6jp8n1j9596qy__gdvty00000gn/T/ipykernel_70607/3816208988.py:15: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value 'gene_id
# FBgn0267594        0.000000
# FBgn0259849        0.000000
# FBgn0085494        0.000000
# FBgn0085506        0.000000
# FBgn0259870        0.000000
#                    ...
# LexA-p65           0.000000
# mCD8-GFP           0.000000
# myr-GFP-p10     7606.686392
# nls-tdTomato    6961.265464
# unc84-2xEGFP       0.000000
# Name: Q6_D04_Sample_Q6_Pool_01, Length: 17713, dtype: float64' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   getDat.iloc[:,i] = getDat.iloc[:,i]*(1E6/getDat.iloc[:,i].sum())
# /var/folders/kf/mfw6jp8n1j9596qy__gdvty00000gn/T/ipykernel_70607/3816208988.py:15: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value 'gene_id
# FBgn0267594        0.000000
# FBgn0259849        0.000000
# FBgn0085494        0.000000
# FBgn0085506        0.000000
# FBgn0259870        0.000000
#                    ...
# LexA-p65           0.000000
# mCD8-GFP           0.000000
# myr-GFP-p10     8801.928982
# nls-tdTomato    9675.693149
# unc84-2xEGFP       0.000000
# Name: Q6_E04_Sample_Q6_Pool_01, Length: 17713, dtype: float64' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   getDat.iloc[:,i] = getDat.iloc[:,i]*(1E6/getDat.iloc[:,i].sum())
# /var/folders/kf/mfw6jp8n1j9596qy__gdvty00000gn/T/ipykernel_70607/3816208988.py:15: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value 'gene_id
# FBgn0267594         0.000000
# FBgn0259849         0.000000
# FBgn0085494         0.000000
# FBgn0085506         0.000000
# FBgn0259870         0.000000
#                     ...
# LexA-p65            0.000000
# mCD8-GFP            0.000000
# myr-GFP-p10     10553.982902
# nls-tdTomato     6032.461193
# unc84-2xEGFP        0.000000
# Name: Q6_F04_Sample_Q6_Pool_01, Length: 17713, dtype: float64' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   getDat.iloc[:,i] = getDat.iloc[:,i]*(1E6/getDat.iloc[:,i].sum())
# /var/folders/kf/mfw6jp8n1j9596qy__gdvty00000gn/T/ipykernel_70607/3816208988.py:15: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value 'gene_id
# FBgn0267594        0.000000
# FBgn0259849        0.000000
# FBgn0085494        0.000000
# FBgn0085506        0.000000
# FBgn0259870        0.000000
#                    ...
# LexA-p65           0.000000
# mCD8-GFP           0.000000
# myr-GFP-p10     8792.255382
# nls-tdTomato    6992.959614
# unc84-2xEGFP       0.000000
# Name: Q6_G04_Sample_Q6_Pool_01, Length: 17713, dtype: float64' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   getDat.iloc[:,i] = getDat.iloc[:,i]*(1E6/getDat.iloc[:,i].sum())
# /var/folders/kf/mfw6jp8n1j9596qy__gdvty00000gn/T/ipykernel_70607/3816208988.py:15: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value 'gene_id
# FBgn0267594      0.000000
# FBgn0259849      0.000000
# FBgn0085494      0.000000
# FBgn0085506      0.000000
# FBgn0259870      0.000000
#                   ...
# LexA-p65         0.000000
# mCD8-GFP         0.000000
# myr-GFP-p10     29.224928
# nls-tdTomato    53.136233
# unc84-2xEGFP     0.000000
# Name: Q5_A05_Sample_3_Q5_5, Length: 17713, dtype: float64' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   getDat.iloc[:,i] = getDat.iloc[:,i]*(1E6/getDat.iloc[:,i].sum())
# /var/folders/kf/mfw6jp8n1j9596qy__gdvty00000gn/T/ipykernel_70607/3816208988.py:15: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value 'gene_id
# FBgn0267594      0.000000
# FBgn0259849      0.000000
# FBgn0085494      0.000000
# FBgn0085506      0.000000
# FBgn0259870      0.000000
#                   ...
# LexA-p65         0.000000
# mCD8-GFP         0.000000
# myr-GFP-p10     89.522538
# nls-tdTomato    51.155736
# unc84-2xEGFP     0.000000
# Name: Q5_B05_Sample_3_Q5_5, Length: 17713, dtype: float64' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   getDat.iloc[:,i] = getDat.iloc[:,i]*(1E6/getDat.iloc[:,i].sum())
# /var/folders/kf/mfw6jp8n1j9596qy__gdvty00000gn/T/ipykernel_70607/3816208988.py:15: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value 'gene_id
# FBgn0267594      0.000000
# FBgn0259849      0.000000
# FBgn0085494      0.000000
# FBgn0085506      0.000000
# FBgn0259870      0.000000
#                   ...
# LexA-p65         0.000000
# mCD8-GFP         0.000000
# myr-GFP-p10     71.856595
# nls-tdTomato    38.494604
# unc84-2xEGFP     0.000000
# Name: Q5_C05_Sample_3_Q5_5, Length: 17713, dtype: float64' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   getDat.iloc[:,i] = getDat.iloc[:,i]*(1E6/getDat.iloc[:,i].sum())
# /var/folders/kf/mfw6jp8n1j9596qy__gdvty00000gn/T/ipykernel_70607/3816208988.py:15: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value 'gene_id
# FBgn0267594      0.000000
# FBgn0259849      0.000000
# FBgn0085494      0.000000
# FBgn0085506      0.000000
# FBgn0259870      0.000000
#                   ...
# LexA-p65         0.000000
# mCD8-GFP         0.000000
# myr-GFP-p10     26.289654
# nls-tdTomato    32.131799
# unc84-2xEGFP     0.000000
# Name: Q5_D05_Sample_3_Q5_5, Length: 17713, dtype: float64' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   getDat.iloc[:,i] = getDat.iloc[:,i]*(1E6/getDat.iloc[:,i].sum())
# /var/folders/kf/mfw6jp8n1j9596qy__gdvty00000gn/T/ipykernel_70607/3816208988.py:15: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value 'gene_id
# FBgn0267594      0.000000
# FBgn0259849      0.000000
# FBgn0085494      0.000000
# FBgn0085506      0.000000
# FBgn0259870      0.000000
#                   ...
# LexA-p65         0.000000
# mCD8-GFP         0.000000
# myr-GFP-p10     24.299565
# nls-tdTomato    26.729522
# unc84-2xEGFP     0.000000
# Name: Q5_E05_Sample_3_Q5_5, Length: 17713, dtype: float64' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   getDat.iloc[:,i] = getDat.iloc[:,i]*(1E6/getDat.iloc[:,i].sum())
# /var/folders/kf/mfw6jp8n1j9596qy__gdvty00000gn/T/ipykernel_70607/3816208988.py:15: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value 'gene_id
# FBgn0267594      0.000000
# FBgn0259849      0.000000
# FBgn0085494      0.000000
# FBgn0085506      0.000000
# FBgn0259870      0.000000
#                   ...
# LexA-p65         0.000000
# mCD8-GFP         0.000000
# myr-GFP-p10     27.289868
# nls-tdTomato    39.694353
# unc84-2xEGFP     0.000000
# Name: Q5_F05_Sample_3_Q5_5, Length: 17713, dtype: float64' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   getDat.iloc[:,i] = getDat.iloc[:,i]*(1E6/getDat.iloc[:,i].sum())
# /var/folders/kf/mfw6jp8n1j9596qy__gdvty00000gn/T/ipykernel_70607/3816208988.py:15: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value 'gene_id
# FBgn0267594      0.000000
# FBgn0259849      0.000000
# FBgn0085494      0.000000
# FBgn0085506      0.000000
# FBgn0259870      0.000000
#                   ...
# LexA-p65         0.000000
# mCD8-GFP         0.000000
# myr-GFP-p10     36.338530
# nls-tdTomato    58.141648
# unc84-2xEGFP     0.000000
# Name: Q5_G05_Sample_3_Q5_5, Length: 17713, dtype: float64' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   getDat.iloc[:,i] = getDat.iloc[:,i]*(1E6/getDat.iloc[:,i].sum())
# /var/folders/kf/mfw6jp8n1j9596qy__gdvty00000gn/T/ipykernel_70607/3816208988.py:15: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value 'gene_id
# FBgn0267594      0.000000
# FBgn0259849      0.000000
# FBgn0085494      0.000000
# FBgn0085506      0.000000
# FBgn0259870      0.000000
#                   ...
# LexA-p65         0.000000
# mCD8-GFP         0.000000
# myr-GFP-p10     45.574150
# nls-tdTomato    55.168708
# unc84-2xEGFP     0.000000
# Name: Q5_H05_Sample_3_Q5_5, Length: 17713, dtype: float64' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   getDat.iloc[:,i] = getDat.iloc[:,i]*(1E6/getDat.iloc[:,i].sum())

# %% [markdown]
# ### Get the single cell data

# %%
PEN1s_singleCell = getSubDat(cellsMeta, cellsCount,"62862_CB_facs",0)
PEN2s_singleCell = getSubDat(cellsMeta, cellsCount,"02232_CB_facs",0)
wholeBrain_singleCell = getSubDat(cellsMeta, cellsCount,"qRNA_CB_10pg",0)
ERCCs_singleCell = getSubDat(cellsMeta, cellsCount,"ERCC",0)

# %% [markdown]
# ### Filter the single cell data

# %%
PEN1_plates = [389,391,392,394,395,396]
PEN2_plates = [386,387,388,390,393]

# %% [markdown]
# #### Threshold 1: Select the single cells where more genes are detected than in the ERCC alone wells.

# %%
# Get all of the PEN1 ERCC controls
PEN1_ERCCs = [[nm for nm in ERCCs_singleCell.columns if str(plt) in nm] for plt in PEN1_plates]
PEN1_ERCCs = [item for sublist in PEN1_ERCCs for item in sublist]
PEN1_ERCCs = ERCCs_singleCell[PEN1_ERCCs]

# Get all of the PEN2 ERCC controls
PEN2_ERCCs = [[nm for nm in ERCCs_singleCell.columns if str(plt) in nm] for plt in PEN2_plates]
PEN2_ERCCs = [item for sublist in PEN2_ERCCs for item in sublist]
PEN2_ERCCs = ERCCs_singleCell[PEN2_ERCCs]

# Threshold
thresh1_PEN1 = [PEN1s_singleCell.columns[i] for i,val in enumerate(PEN1s_singleCell.sum()) if val > PEN1_ERCCs.sum().max()]
thresh1_PEN2 = [PEN2s_singleCell.columns[i] for i,val in enumerate(PEN2s_singleCell.sum()) if val > PEN2_ERCCs.sum().max()]

# %% [markdown]
# #### Threshold 2: Select the single cells that are within 2 SD of the mean for number of ERCC genes detected

# %%
thresh2_PEN1 = []
for plate in PEN1_plates:
    PEN1_wells = [nm for nm in PEN1s_singleCell.columns if str(plate) in nm]
    PEN1_plate_dat = PEN1s_singleCell[PEN1_wells]
    ERCCs_det_plate = [sum(sum([PEN1_plate_dat[w].loc[
        [i for i in PEN1_plate_dat.index if 'ERCC' in i]] > 0]))
                       for w in PEN1_wells]
    thresh2_PEN1.append([PEN1_wells[l] for l,val in  enumerate(ERCCs_det_plate) 
                         if val > (np.mean(ERCCs_det_plate) - 2*np.std(ERCCs_det_plate)) and
                         val < (np.mean(ERCCs_det_plate) + 2*np.std(ERCCs_det_plate))])   
thresh2_PEN1 = [item for sublist in thresh2_PEN1 for item in sublist]

thresh2_PEN2 = []
for plate in PEN2_plates:
    PEN2_wells = [nm for nm in PEN2s_singleCell.columns if str(plate) in nm]
    PEN2_plate_dat = PEN2s_singleCell[PEN2_wells]
    ERCCs_det_plate = [sum(sum([PEN2_plate_dat[w].loc[
        [i for i in PEN2_plate_dat.index if 'ERCC' in i]] > 0]))
                       for w in PEN2_wells]
    thresh2_PEN2.append([PEN2_wells[l] for l,val in  enumerate(ERCCs_det_plate) 
                         if val > (np.mean(ERCCs_det_plate) - 2*np.std(ERCCs_det_plate)) and
                         val < (np.mean(ERCCs_det_plate) + 2*np.std(ERCCs_det_plate))])   
thresh2_PEN2 = [item for sublist in thresh2_PEN2 for item in sublist]

# %% [markdown]
# #### Combine the different thresholds

# %%
thresh_PEN1 = [t for t in thresh1_PEN1 if t in thresh2_PEN1]
thresh_PEN2 = [t for t in thresh1_PEN2 if t in thresh2_PEN2]

# %% [markdown]
# #### Select only the data that passes the threshold and normalize

# %%
PEN1s_singleCell = PEN1s_singleCell[thresh_PEN1]
for i in range(0,len(PEN1s_singleCell.columns)):
    PEN1s_singleCell.iloc[:,i] = PEN1s_singleCell.iloc[:,i]*(1E6/PEN1s_singleCell.iloc[:,i].sum())

PEN2s_singleCell = PEN2s_singleCell[thresh_PEN2]
for i in range(0,len(PEN2s_singleCell.columns)):
    PEN2s_singleCell.iloc[:,i] = PEN2s_singleCell.iloc[:,i]*(1E6/PEN2s_singleCell.iloc[:,i].sum())
# Out:
# /var/folders/kf/mfw6jp8n1j9596qy__gdvty00000gn/T/ipykernel_70607/3279156493.py:3: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value 'gene_id
# ERCC-00002      112689.322583
# ERCC-00003        6216.562429
# ERCC-00004       54442.016427
# ERCC-00009       11704.719564
# ERCC-00012           0.000000
#                     ...
# LexA-p65             0.000000
# mCD8-GFP             0.000000
# myr-GFP-p10         37.676136
# nls-tdTomato         0.000000
# unc84-2xEGFP         0.000000
# Name: 62862_CB_facs_direct_Plate_1-Q8_B01_Plate_389_Q8, Length: 17713, dtype: float64' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   PEN1s_singleCell.iloc[:,i] = PEN1s_singleCell.iloc[:,i]*(1E6/PEN1s_singleCell.iloc[:,i].sum())
# /var/folders/kf/mfw6jp8n1j9596qy__gdvty00000gn/T/ipykernel_70607/3279156493.py:3: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value 'gene_id
# ERCC-00002      84733.015793
# ERCC-00003       8331.735803
# ERCC-00004      41761.904060
# ERCC-00009       3893.058853
# ERCC-00012          0.000000
#                     ...
# LexA-p65            0.000000
# mCD8-GFP            0.000000
# myr-GFP-p10         0.000000
# nls-tdTomato       14.746435
# unc84-2xEGFP        0.000000
# Name: 62862_CB_facs_direct_Plate_1-Q8_C01_Plate_389_Q8, Length: 17713, dtype: float64' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   PEN1s_singleCell.iloc[:,i] = PEN1s_singleCell.iloc[:,i]*(1E6/PEN1s_singleCell.iloc[:,i].sum())
# /var/folders/kf/mfw6jp8n1j9596qy__gdvty00000gn/T/ipykernel_70607/3279156493.py:3: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value 'gene_id
# ERCC-00002      42256.467000
# ERCC-00003       2253.498320
# ERCC-00004      16267.019310
# ERCC-00009       2455.908349
# ERCC-00012          0.000000
#                     ...
# LexA-p65            0.000000
# mCD8-GFP            0.000000
# myr-GFP-p10         0.000000
# nls-tdTomato        0.000000
# unc84-2xEGFP        0.000000
# Name: 62862_CB_facs_direct_Plate_1-Q8_E01_Plate_389_Q8, Length: 17713, dtype: float64' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   PEN1s_singleCell.iloc[:,i] = PEN1s_singleCell.iloc[:,i]*(1E6/PEN1s_singleCell.iloc[:,i].sum())
# /var/folders/kf/mfw6jp8n1j9596qy__gdvty00000gn/T/ipykernel_70607/3279156493.py:3: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value 'gene_id
# ERCC-00002      51863.295827
# ERCC-00003       7162.371705
# ERCC-00004      22202.784294
# ERCC-00009       2646.839980
# ERCC-00012          0.000000
#                     ...
# LexA-p65            0.000000
# mCD8-GFP            0.000000
# myr-GFP-p10      8315.394271
# nls-tdTomato     4742.728290
# unc84-2xEGFP        0.000000
# Name: 62862_CB_facs_direct_Plate_1-Q8_F01_Plate_389_Q8, Length: 17713, dtype: float64' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   PEN1s_singleCell.iloc[:,i] = PEN1s_singleCell.iloc[:,i]*(1E6/PEN1s_singleCell.iloc[:,i].sum())
# /var/folders/kf/mfw6jp8n1j9596qy__gdvty00000gn/T/ipykernel_70607/3279156493.py:3: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value 'gene_id
# ERCC-00002      32447.007661
# ERCC-00003       1947.612465
# ERCC-00004      16261.304072
# ERCC-00009          7.200046
# ERCC-00012          3.600023
#                     ...
# LexA-p65            0.000000
# mCD8-GFP            0.000000
# myr-GFP-p10        18.000115
# nls-tdTomato     9651.661771
# unc84-2xEGFP        0.000000
# Name: 62862_CB_facs_direct_Plate_1-Q8_G01_Plate_389_Q8, Length: 17713, dtype: float64' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   PEN1s_singleCell.iloc[:,i] = PEN1s_singleCell.iloc[:,i]*(1E6/PEN1s_singleCell.iloc[:,i].sum())
# /var/folders/kf/mfw6jp8n1j9596qy__gdvty00000gn/T/ipykernel_70607/3279156493.py:3: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value 'gene_id
# ERCC-00002      159164.345404
# ERCC-00003       14763.231198
# ERCC-00004       72590.529248
# ERCC-00009        4252.553389
# ERCC-00012           0.000000
#                     ...
# LexA-p65             0.000000
# mCD8-GFP             0.000000
# myr-GFP-p10       4512.534819
# nls-tdTomato       148.560817
# unc84-2xEGFP         0.000000
# Name: 62862_CB_facs_direct_Plate_1-Q8_A02_Plate_389_Q8, Length: 17713, dtype: float64' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   PEN1s_singleCell.iloc[:,i] = PEN1s_singleCell.iloc[:,i]*(1E6/PEN1s_singleCell.iloc[:,i].sum())
# /var/folders/kf/mfw6jp8n1j9596qy__gdvty00000gn/T/ipykernel_70607/3279156493.py:3: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value 'gene_id
# ERCC-00002      67517.624771
# ERCC-00003       5424.599108
# ERCC-00004      23447.933166
# ERCC-00009          0.000000
# ERCC-00012          0.000000
#                     ...
# LexA-p65            0.000000
# mCD8-GFP            0.000000
# myr-GFP-p10      4720.643498
# nls-tdTomato    10124.538029
# unc84-2xEGFP        0.000000
# Name: 62862_CB_facs_direct_Plate_1-Q8_C02_Plate_389_Q8, Length: 17713, dtype: float64' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   PEN1s_singleCell.iloc[:,i] = PEN1s_singleCell.iloc[:,i]*(1E6/PEN1s_singleCell.iloc[:,i].sum())
# /var/folders/kf/mfw6jp8n1j9596qy__gdvty00000gn/T/ipykernel_70607/3279156493.py:3: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value 'gene_id
# ERCC-00002      58124.145474
# ERCC-00003       2417.281925
# ERCC-00004      23822.805578
# ERCC-00009       4572.053596
# ERCC-00012          0.000000
#                     ...
# LexA-p65            0.000000
# mCD8-GFP            0.000000
# myr-GFP-p10         0.000000
# nls-tdTomato      743.779054
# unc84-2xEGFP        0.000000
# Name: 62862_CB_facs_direct_Plate_1-Q8_D02_Plate_389_Q8, Length: 17713, dtype: float64' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   PEN1s_singleCell.iloc[:,i] = PEN1s_singleCell.iloc[:,i]*(1E6/PEN1s_singleCell.iloc[:,i].sum())
# /var/folders/kf/mfw6jp8n1j9596qy__gdvty00000gn/T/ipykernel_70607/3279156493.py:3: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value 'gene_id
# ERCC-00002      37352.902021
# ERCC-00003       2408.433147
# ERCC-00004      20199.371468
# ERCC-00009       2255.132545
# ERCC-00012          0.000000
#                     ...
# LexA-p65            0.000000
# mCD8-GFP            0.000000
# myr-GFP-p10     10593.878465
# nls-tdTomato        4.034226
# unc84-2xEGFP        0.000000
# Name: 62862_CB_facs_direct_Plate_1-Q8_F02_Plate_389_Q8, Length: 17713, dtype: float64' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   PEN1s_singleCell.iloc[:,i] = PEN1s_singleCell.iloc[:,i]*(1E6/PEN1s_singleCell.iloc[:,i].sum())
# /var/folders/kf/mfw6jp8n1j9596qy__gdvty00000gn/T/ipykernel_70607/3279156493.py:3: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value 'gene_id
# ERCC-00002      52410.940644
# ERCC-00003       1650.689241
# ERCC-00004      26442.172930
# ERCC-00009       1825.101689
# ERCC-00012          0.000000
#                     ...
# LexA-p65            0.000000
# mCD8-GFP            0.000000
# myr-GFP-p10      3357.439625
# nls-tdTomato     1233.345168
# unc84-2xEGFP        0.000000
# Name: 62862_CB_facs_direct_Plate_1-Q8_G02_Plate_389_Q8, Length: 17713, dtype: float64' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   PEN1s_singleCell.iloc[:,i] = PEN1s_singleCell.iloc[:,i]*(1E6/PEN1s_singleCell.iloc[:,i].sum())
# /var/folders/kf/mfw6jp8n1j9596qy__gdvty00000gn/T/ipykernel_70607/3279156493.py:3: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value 'gene_id
# ERCC-00002      78563.693510
# ERCC-00003       9297.165949
# ERCC-00004      44425.662291
# ERCC-00009       5691.872904
# ERCC-00012          0.000000
#                     ...
# LexA-p65            0.000000
# mCD8-GFP            0.000000
# myr-GFP-p10      1796.043422
# nls-tdTomato     2007.342648
# unc84-2xEGFP        0.000000
# Name: 62862_CB_facs_direct_Plate_1-Q8_H02_Plate_389_Q8, Length: 17713, dtype: float64' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   PEN1s_singleCell.iloc[:,i] = PEN1s_singleCell.iloc[:,i]*(1E6/PEN1s_singleCell.iloc[:,i].sum())
# /var/folders/kf/mfw6jp8n1j9596qy__gdvty00000gn/T/ipykernel_70607/3279156493.py:3: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value 'gene_id
# ERCC-00002      119981.308641
# ERCC-00003        4771.215307
# ERCC-00004       43285.252272
# ERCC-00009        6382.115321
# ERCC-00012           0.000000
#                     ...
# LexA-p65             0.000000
# mCD8-GFP             0.000000
# myr-GFP-p10         36.890840
# nls-tdTomato        36.890840
# unc84-2xEGFP         0.000000
# Name: 62862_CB_facs_direct_Plate_1-Q8_A03_Plate_389_Q8, Length: 17713, dtype: float64' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   PEN1s_singleCell.iloc[:,i] = PEN1s_singleCell.iloc[:,i]*(1E6/PEN1s_singleCell.iloc[:,i].sum())
# /var/folders/kf/mfw6jp8n1j9596qy__gdvty00000gn/T/ipykernel_70607/3279156493.py:3: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value 'gene_id
# ERCC-00002      21351.898613
# ERCC-00003        462.533105
# ERCC-00004      11196.727321
# ERCC-00009        770.888509
# ERCC-00012          0.000000
#                     ...
# LexA-p65            0.000000
# mCD8-GFP            0.000000
# myr-GFP-p10         3.426171
# nls-tdTomato       13.704685
# unc84-2xEGFP        0.000000
# Name: 62862_CB_facs_direct_Plate_1-Q8_B03_Plate_389_Q8, Length: 17713, dtype: float64' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   PEN1s_singleCell.iloc[:,i] = PEN1s_singleCell.iloc[:,i]*(1E6/PEN1s_singleCell.iloc[:,i].sum())
# /var/folders/kf/mfw6jp8n1j9596qy__gdvty00000gn/T/ipykernel_70607/3279156493.py:3: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value 'gene_id
# ERCC-00002      108244.354980
# ERCC-00003        1627.866270
# ERCC-00004       56940.311570
# ERCC-00009        4446.000350
# ERCC-00012         157.535445
#                     ...
# LexA-p65             0.000000
# mCD8-GFP             0.000000
# myr-GFP-p10         17.503938
# nls-tdTomato        17.503938
# unc84-2xEGFP         0.000000
# Name: 62862_CB_facs_direct_Plate_1-Q8_C03_Plate_389_Q8, Length: 17713, dtype: float64' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   PEN1s_singleCell.iloc[:,i] = PEN1s_singleCell.iloc[:,i]*(1E6/PEN1s_singleCell.iloc[:,i].sum())
# /var/folders/kf/mfw6jp8n1j9596qy__gdvty00000gn/T/ipykernel_70607/3279156493.py:3: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value 'gene_id
# ERCC-00002      46590.156459
# ERCC-00003       2160.671437
# ERCC-00004      25515.466716
# ERCC-00009       2909.848970
# ERCC-00012         32.572936
#                     ...
# LexA-p65            0.000000
# mCD8-GFP            0.000000
# myr-GFP-p10        54.288227
# nls-tdTomato       32.572936
# unc84-2xEGFP        0.000000
# Name: 62862_CB_facs_direct_Plate_1-Q8_D03_Plate_389_Q8, Length: 17713, dtype: float64' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   PEN1s_singleCell.iloc[:,i] = PEN1s_singleCell.iloc[:,i]*(1E6/PEN1s_singleCell.iloc[:,i].sum())
# /var/folders/kf/mfw6jp8n1j9596qy__gdvty00000gn/T/ipykernel_70607/3279156493.py:3: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value 'gene_id
# ERCC-00002      70064.528419
# ERCC-00003       4369.359716
# ERCC-00004      41455.342048
# ERCC-00009       3524.061242
# ERCC-00012          0.000000
#                     ...
# LexA-p65            0.000000
# mCD8-GFP            0.000000
# myr-GFP-p10      1833.464295
# nls-tdTomato     2071.576541
# unc84-2xEGFP        0.000000
# Name: 62862_CB_facs_direct_Plate_1-Q8_E03_Plate_389_Q8, Length: 17713, dtype: float64' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   PEN1s_singleCell.iloc[:,i] = PEN1s_singleCell.iloc[:,i]*(1E6/PEN1s_singleCell.iloc[:,i].sum())
# /var/folders/kf/mfw6jp8n1j9596qy__gdvty00000gn/T/ipykernel_70607/3279156493.py:3: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value 'gene_id
# ERCC-00002      35768.221922
# ERCC-00003       1554.372113
# ERCC-00004      16334.154678
# ERCC-00009       2684.824559
# ERCC-00012          0.000000
#                     ...
# LexA-p65            0.000000
# mCD8-GFP            0.000000
# myr-GFP-p10         4.415830
# nls-tdTomato        0.000000
# unc84-2xEGFP        0.000000
# Name: 62862_CB_facs_direct_Plate_1-Q8_F03_Plate_389_Q8, Length: 17713, dtype: float64' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   PEN1s_singleCell.iloc[:,i] = PEN1s_singleCell.iloc[:,i]*(1E6/PEN1s_singleCell.iloc[:,i].sum())
# /var/folders/kf/mfw6jp8n1j9596qy__gdvty00000gn/T/ipykernel_70607/3279156493.py:3: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value 'gene_id
# ERCC-00002      126891.334250
# ERCC-00003        6762.952774
# ERCC-00004       61521.582498
# ERCC-00009       14983.297308
# ERCC-00012           0.000000
#                     ...
# LexA-p65             0.000000
# mCD8-GFP             0.000000
# myr-GFP-p10         32.750377
# nls-tdTomato        16.375188
# unc84-2xEGFP         0.000000
# Name: 62862_CB_facs_direct_Plate_1-Q8_G03_Plate_389_Q8, Length: 17713, dtype: float64' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   PEN1s_singleCell.iloc[:,i] = PEN1s_singleCell.iloc[:,i]*(1E6/PEN1s_singleCell.iloc[:,i].sum())
# /var/folders/kf/mfw6jp8n1j9596qy__gdvty00000gn/T/ipykernel_70607/3279156493.py:3: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value 'gene_id
# ERCC-00002      117704.132682
# ERCC-00003        4320.669476
# ERCC-00004       53455.019557
# ERCC-00009        7261.756769
# ERCC-00012          30.320488
#                     ...
# LexA-p65             0.000000
# mCD8-GFP             0.000000
# myr-GFP-p10         45.480731
# nls-tdTomato        90.961463
# unc84-2xEGFP        15.160244
# Name: 62862_CB_facs_direct_Plate_1-Q8_H03_Plate_389_Q8, Length: 17713, dtype: float64' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   PEN1s_singleCell.iloc[:,i] = PEN1s_singleCell.iloc[:,i]*(1E6/PEN1s_singleCell.iloc[:,i].sum())
# /var/folders/kf/mfw6jp8n1j9596qy__gdvty00000gn/T/ipykernel_70607/3279156493.py:3: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value 'gene_id
# ERCC-00002      65020.650905
# ERCC-00003       4752.154193
# ERCC-00004      25242.324922
# ERCC-00009       2110.515539
# ERCC-00012          6.988462
#                     ...
# LexA-p65            0.000000
# mCD8-GFP            0.000000
# myr-GFP-p10        20.965386
# nls-tdTomato     1642.288582
# unc84-2xEGFP        0.000000
# Name: 62862_CB_facs_direct_Plate_1-Q8_A04_Plate_389_Q8, Length: 17713, dtype: float64' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   PEN1s_singleCell.iloc[:,i] = PEN1s_singleCell.iloc[:,i]*(1E6/PEN1s_singleCell.iloc[:,i].sum())
# /var/folders/kf/mfw6jp8n1j9596qy__gdvty00000gn/T/ipykernel_70607/3279156493.py:3: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value 'gene_id
# ERCC-00002      117635.648890
# ERCC-00003        2702.632804
# ERCC-00004       47651.683650
# ERCC-00009        4319.039983
# ERCC-00012           0.000000
#                     ...
# LexA-p65             0.000000
# mCD8-GFP             0.000000
# myr-GFP-p10       1913.826100
# nls-tdTomato       155.175089
# unc84-2xEGFP         0.000000
# Name: 62862_CB_facs_direct_Plate_1-Q8_B04_Plate_389_Q8, Length: 17713, dtype: float64' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   PEN1s_singleCell.iloc[:,i] = PEN1s_singleCell.iloc[:,i]*(1E6/PEN1s_singleCell.iloc[:,i].sum())
# /var/folders/kf/mfw6jp8n1j9596qy__gdvty00000gn/T/ipykernel_70607/3279156493.py:3: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value 'gene_id
# ERCC-00002      70126.556783
# ERCC-00003       3603.119720
# ERCC-00004      32898.049616
# ERCC-00009       2137.254244
# ERCC-00012          0.000000
#                     ...
# LexA-p65            0.000000
# mCD8-GFP            0.000000
# myr-GFP-p10      2215.582933
# nls-tdTomato        0.000000
# unc84-2xEGFP        0.000000
# Name: 62862_CB_facs_direct_Plate_1-Q8_C04_Plate_389_Q8, Length: 17713, dtype: float64' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   PEN1s_singleCell.iloc[:,i] = PEN1s_singleCell.iloc[:,i]*(1E6/PEN1s_singleCell.iloc[:,i].sum())
# /var/folders/kf/mfw6jp8n1j9596qy__gdvty00000gn/T/ipykernel_70607/3279156493.py:3: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value 'gene_id
# ERCC-00002      37656.832245
# ERCC-00003       1162.353424
# ERCC-00004      15819.971967
# ERCC-00009       2811.869680
# ERCC-00012          0.000000
#                     ...
# LexA-p65            0.000000
# mCD8-GFP            0.000000
# myr-GFP-p10      8871.491573
# nls-tdTomato     3546.887286
# unc84-2xEGFP        0.000000
# Name: 62862_CB_facs_direct_Plate_1-Q8_D04_Plate_389_Q8, Length: 17713, dtype: float64' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   PEN1s_singleCell.iloc[:,i] = PEN1s_singleCell.iloc[:,i]*(1E6/PEN1s_singleCell.iloc[:,i].sum())
# /var/folders/kf/mfw6jp8n1j9596qy__gdvty00000gn/T/ipykernel_70607/3279156493.py:3: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value 'gene_id
# ERCC-00002      43589.743590
# ERCC-00003       1093.514329
# ERCC-00004      21314.102564
# ERCC-00009       2752.639517
# ERCC-00012          0.000000
#                     ...
# LexA-p65            0.000000
# mCD8-GFP            0.000000
# myr-GFP-p10      5684.389140
# nls-tdTomato     4515.460030
# unc84-2xEGFP        0.000000
# Name: 62862_CB_facs_direct_Plate_1-Q8_E04_Plate_389_Q8, Length: 17713, dtype: float64' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   PEN1s_singleCell.iloc[:,i] = PEN1s_singleCell.iloc[:,i]*(1E6/PEN1s_singleCell.iloc[:,i].sum())
# /var/folders/kf/mfw6jp8n1j9596qy__gdvty00000gn/T/ipykernel_70607/3279156493.py:3: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value 'gene_id
# ERCC-00002      145062.830216
# ERCC-00003       27809.510210
# ERCC-00004       78734.113951
# ERCC-00009       11102.384692
# ERCC-00012           0.000000
#                     ...
# LexA-p65             0.000000
# mCD8-GFP             0.000000
# myr-GFP-p10         17.849493
# nls-tdTomato        17.849493
# unc84-2xEGFP         0.000000
# Name: 62862_CB_facs_direct_Plate_1-Q8_F04_Plate_389_Q8, Length: 17713, dtype: float64' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   PEN1s_singleCell.iloc[:,i] = PEN1s_singleCell.iloc[:,i]*(1E6/PEN1s_singleCell.iloc[:,i].sum())
# /var/folders/kf/mfw6jp8n1j9596qy__gdvty00000gn/T/ipykernel_70607/3279156493.py:3: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value 'gene_id
# ERCC-00002      55150.820454
# ERCC-00003       7677.572718
# ERCC-00004      31471.893776
# ERCC-00009       2554.062267
# ERCC-00012          0.000000
#                     ...
# LexA-p65            0.000000
# mCD8-GFP            0.000000
# myr-GFP-p10      4961.958320
# nls-tdTomato    11839.463339
# unc84-2xEGFP       15.385917
# Name: 62862_CB_facs_direct_Plate_1-Q8_G04_Plate_389_Q8, Length: 17713, dtype: float64' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   PEN1s_singleCell.iloc[:,i] = PEN1s_singleCell.iloc[:,i]*(1E6/PEN1s_singleCell.iloc[:,i].sum())
# /var/folders/kf/mfw6jp8n1j9596qy__gdvty00000gn/T/ipykernel_70607/3279156493.py:3: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value 'gene_id
# ERCC-00002      68207.330188
# ERCC-00003       5392.845648
# ERCC-00004      33573.800347
# ERCC-00009      10667.943575
# ERCC-00012          0.000000
#                     ...
# LexA-p65            0.000000
# mCD8-GFP            0.000000
# myr-GFP-p10      7410.256612
# nls-tdTomato     6633.121649
# unc84-2xEGFP        0.000000
# Name: 62862_CB_facs_direct_Plate_1-Q8_H04_Plate_389_Q8, Length: 17713, dtype: float64' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   PEN1s_singleCell.iloc[:,i] = PEN1s_singleCell.iloc[:,i]*(1E6/PEN1s_singleCell.iloc[:,i].sum())
# /var/folders/kf/mfw6jp8n1j9596qy__gdvty00000gn/T/ipykernel_70607/3279156493.py:3: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value 'gene_id
# ERCC-00002      77955.002573
# ERCC-00003      10440.151551
# ERCC-00004      28570.092146
# ERCC-00009       6136.863277
# ERCC-00012          0.000000
#                     ...
# LexA-p65            0.000000
# mCD8-GFP            0.000000
# myr-GFP-p10      3143.271435
# nls-tdTomato     2890.687123
# unc84-2xEGFP        0.000000
# Name: 62862_CB_facs_direct_Plate_1-Q8_A05_Plate_389_Q8, Length: 17713, dtype: float64' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   PEN1s_singleCell.iloc[:,i] = PEN1s_singleCell.iloc[:,i]*(1E6/PEN1s_singleCell.iloc[:,i].sum())
# /var/folders/kf/mfw6jp8n1j9596qy__gdvty00000gn/T/ipykernel_70607/3279156493.py:3: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value 'gene_id
# ERCC-00002      39955.646743
# ERCC-00003       1734.906315
# ERCC-00004      25269.287632
# ERCC-00009       1878.224663
# ERCC-00012          0.000000
#                     ...
# LexA-p65            0.000000
# mCD8-GFP            0.000000
# myr-GFP-p10      9142.201973
# nls-tdTomato      784.479377
# unc84-2xEGFP        0.000000
# Name: 62862_CB_facs_direct_Plate_1-Q8_B05_Plate_389_Q8, Length: 17713, dtype: float64' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   PEN1s_singleCell.iloc[:,i] = PEN1s_singleCell.iloc[:,i]*(1E6/PEN1s_singleCell.iloc[:,i].sum())
# /var/folders/kf/mfw6jp8n1j9596qy__gdvty00000gn/T/ipykernel_70607/3279156493.py:3: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value 'gene_id
# ERCC-00002      63678.519626
# ERCC-00003       3120.741945
# ERCC-00004      26537.295064
# ERCC-00009       1846.072700
# ERCC-00012          0.000000
#                     ...
# LexA-p65            0.000000
# mCD8-GFP            0.000000
# myr-GFP-p10       626.346095
# nls-tdTomato        0.000000
# unc84-2xEGFP        0.000000
# Name: 62862_CB_facs_direct_Plate_1-Q8_C05_Plate_389_Q8, Length: 17713, dtype: float64' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   PEN1s_singleCell.iloc[:,i] = PEN1s_singleCell.iloc[:,i]*(1E6/PEN1s_singleCell.iloc[:,i].sum())
# /var/folders/kf/mfw6jp8n1j9596qy__gdvty00000gn/T/ipykernel_70607/3279156493.py:3: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value 'gene_id
# ERCC-00002      29337.454833
# ERCC-00003       5151.874435
# ERCC-00004      18151.535682
# ERCC-00009       2335.986902
# ERCC-00012          0.000000
#                     ...
# LexA-p65            0.000000
# mCD8-GFP            0.000000
# myr-GFP-p10      7727.811653
# nls-tdTomato     3888.606594
# unc84-2xEGFP        0.000000
# Name: 62862_CB_facs_direct_Plate_1-Q8_D05_Plate_389_Q8, Length: 17713, dtype: float64' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   PEN1s_singleCell.iloc[:,i] = PEN1s_singleCell.iloc[:,i]*(1E6/PEN1s_singleCell.iloc[:,i].sum())
# /var/folders/kf/mfw6jp8n1j9596qy__gdvty00000gn/T/ipykernel_70607/3279156493.py:3: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value 'gene_id
# ERCC-00002      34594.174247
# ERCC-00003       1626.479302
# ERCC-00004      12666.823656
# ERCC-00009       2787.467895
# ERCC-00012          0.000000
#                     ...
# LexA-p65            0.000000
# mCD8-GFP            0.000000
# myr-GFP-p10     14654.742803
# nls-tdTomato     8942.897981
# unc84-2xEGFP        0.000000
# Name: 62862_CB_facs_direct_Plate_1-Q8_E05_Plate_389_Q8, Length: 17713, dtype: float64' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   PEN1s_singleCell.iloc[:,i] = PEN1s_singleCell.iloc[:,i]*(1E6/PEN1s_singleCell.iloc[:,i].sum())
# /var/folders/kf/mfw6jp8n1j9596qy__gdvty00000gn/T/ipykernel_70607/3279156493.py:3: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value 'gene_id
# ERCC-00002      34193.413048
# ERCC-00003       3999.125191
# ERCC-00004      18308.495017
# ERCC-00009       1571.084897
# ERCC-00012          0.000000
#                     ...
# LexA-p65            0.000000
# mCD8-GFP            0.000000
# myr-GFP-p10       897.125182
# nls-tdTomato       13.389928
# unc84-2xEGFP        0.000000
# Name: 62862_CB_facs_direct_Plate_1-Q8_F05_Plate_389_Q8, Length: 17713, dtype: float64' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   PEN1s_singleCell.iloc[:,i] = PEN1s_singleCell.iloc[:,i]*(1E6/PEN1s_singleCell.iloc[:,i].sum())
# /var/folders/kf/mfw6jp8n1j9596qy__gdvty00000gn/T/ipykernel_70607/3279156493.py:3: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value 'gene_id
# ERCC-00002      144996.846752
# ERCC-00003        8395.522388
# ERCC-00004       54025.646416
# ERCC-00009        5872.924112
# ERCC-00012           0.000000
#                     ...
# LexA-p65             0.000000
# mCD8-GFP             0.000000
# myr-GFP-p10        236.493588
# nls-tdTomato        13.138533
# unc84-2xEGFP         0.000000
# Name: 62862_CB_facs_direct_Plate_1-Q8_G05_Plate_389_Q8, Length: 17713, dtype: float64' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   PEN1s_singleCell.iloc[:,i] = PEN1s_singleCell.iloc[:,i]*(1E6/PEN1s_singleCell.iloc[:,i].sum())
# /var/folders/kf/mfw6jp8n1j9596qy__gdvty00000gn/T/ipykernel_70607/3279156493.py:3: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value 'gene_id
# ERCC-00002      121345.973233
# ERCC-00003        5459.027941
# ERCC-00004       47443.648744
# ERCC-00009        3228.457384
# ERCC-00012           0.000000
#                     ...
# LexA-p65             0.000000
# mCD8-GFP             0.000000
# myr-GFP-p10          0.000000
# nls-tdTomato         0.000000
# unc84-2xEGFP         0.000000
# Name: 62862_CB_facs_direct_Plate_1-Q8_H05_Plate_389_Q8, Length: 17713, dtype: float64' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   PEN1s_singleCell.iloc[:,i] = PEN1s_singleCell.iloc[:,i]*(1E6/PEN1s_singleCell.iloc[:,i].sum())
# /var/folders/kf/mfw6jp8n1j9596qy__gdvty00000gn/T/ipykernel_70607/3279156493.py:3: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value 'gene_id
# ERCC-00002      71602.252865
# ERCC-00003       3472.518936
# ERCC-00004      31470.188386
# ERCC-00009       2377.160614
# ERCC-00012          0.000000
#                     ...
# LexA-p65            0.000000
# mCD8-GFP            0.000000
# myr-GFP-p10      1872.208196
# nls-tdTomato     5189.357157
# unc84-2xEGFP        0.000000
# Name: 62862_CB_facs_direct_Plate_1-Q8_A06_Plate_389_Q8, Length: 17713, dtype: float64' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   PEN1s_singleCell.iloc[:,i] = PEN1s_singleCell.iloc[:,i]*(1E6/PEN1s_singleCell.iloc[:,i].sum())
# /var/folders/kf/mfw6jp8n1j9596qy__gdvty00000gn/T/ipykernel_70607/3279156493.py:3: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value 'gene_id
# ERCC-00002      47231.422549
# ERCC-00003       3280.969340
# ERCC-00004      25116.027951
# ERCC-00009        145.359401
# ERCC-00012          0.000000
#                     ...
# LexA-p65            0.000000
# mCD8-GFP            0.000000
# myr-GFP-p10      3249.820896
# nls-tdTomato     1578.187784
# unc84-2xEGFP        0.000000
# Name: 62862_CB_facs_direct_Plate_1-Q8_D06_Plate_389_Q8, Length: 17713, dtype: float64' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   PEN1s_singleCell.iloc[:,i] = PEN1s_singleCell.iloc[:,i]*(1E6/PEN1s_singleCell.iloc[:,i].sum())
# /var/folders/kf/mfw6jp8n1j9596qy__gdvty00000gn/T/ipykernel_70607/3279156493.py:3: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value 'gene_id
# ERCC-00002      37344.684479
# ERCC-00003       2062.514889
# ERCC-00004      13384.405131
# ERCC-00009        407.487744
# ERCC-00012          0.000000
#                     ...
# LexA-p65            0.000000
# mCD8-GFP            0.000000
# myr-GFP-p10      6262.773174
# nls-tdTomato     7898.993192
# unc84-2xEGFP        0.000000
# Name: 62862_CB_facs_direct_Plate_1-Q8_E06_Plate_389_Q8, Length: 17713, dtype: float64' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   PEN1s_singleCell.iloc[:,i] = PEN1s_singleCell.iloc[:,i]*(1E6/PEN1s_singleCell.iloc[:,i].sum())
# /var/folders/kf/mfw6jp8n1j9596qy__gdvty00000gn/T/ipykernel_70607/3279156493.py:3: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value 'gene_id
# ERCC-00002      44331.305908
# ERCC-00003       3730.980743
# ERCC-00004      27341.093255
# ERCC-00009          0.000000
# ERCC-00012          0.000000
#                     ...
# LexA-p65            0.000000
# mCD8-GFP            0.000000
# myr-GFP-p10     18901.044804
# nls-tdTomato    13149.116159
# unc84-2xEGFP        0.000000
# Name: 62862_CB_facs_direct_Plate_1-Q8_F06_Plate_389_Q8, Length: 17713, dtype: float64' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   PEN1s_singleCell.iloc[:,i] = PEN1s_singleCell.iloc[:,i]*(1E6/PEN1s_singleCell.iloc[:,i].sum())
# /var/folders/kf/mfw6jp8n1j9596qy__gdvty00000gn/T/ipykernel_70607/3279156493.py:3: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value 'gene_id
# ERCC-00002      34834.611106
# ERCC-00003       1872.612042
# ERCC-00004      20568.529043
# ERCC-00009       3503.596724
# ERCC-00012          0.000000
#                     ...
# LexA-p65            0.000000
# mCD8-GFP            0.000000
# myr-GFP-p10     12217.283404
# nls-tdTomato     4792.275979
# unc84-2xEGFP        5.033903
# Name: 62862_CB_facs_direct_Plate_1-Q8_G06_Plate_389_Q8, Length: 17713, dtype: float64' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   PEN1s_singleCell.iloc[:,i] = PEN1s_singleCell.iloc[:,i]*(1E6/PEN1s_singleCell.iloc[:,i].sum())
# /var/folders/kf/mfw6jp8n1j9596qy__gdvty00000gn/T/ipykernel_70607/3279156493.py:3: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value 'gene_id
# ERCC-00002      141612.817267
# ERCC-00003       10392.378922
# ERCC-00004       51195.789754
# ERCC-00009       10842.049164
# ERCC-00012           0.000000
#                     ...
# LexA-p65             0.000000
# mCD8-GFP             0.000000
# myr-GFP-p10       7011.524882
# nls-tdTomato       499.633602
# unc84-2xEGFP         0.000000
# Name: 62862_CB_facs_direct_Plate_1-Q8_A07_Plate_389_Q8, Length: 17713, dtype: float64' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   PEN1s_singleCell.iloc[:,i] = PEN1s_singleCell.iloc[:,i]*(1E6/PEN1s_singleCell.iloc[:,i].sum())
# /var/folders/kf/mfw6jp8n1j9596qy__gdvty00000gn/T/ipykernel_70607/3279156493.py:3: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value 'gene_id
# ERCC-00002      78668.518547
# ERCC-00003       3667.348117
# ERCC-00004      32982.724450
# ERCC-00009       9121.553083
# ERCC-00012          0.000000
#                     ...
# LexA-p65            0.000000
# mCD8-GFP            0.000000
# myr-GFP-p10         7.802868
# nls-tdTomato        0.000000
# unc84-2xEGFP        0.000000
# Name: 62862_CB_facs_direct_Plate_1-Q8_B07_Plate_389_Q8, Length: 17713, dtype: float64' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   PEN1s_singleCell.iloc[:,i] = PEN1s_singleCell.iloc[:,i]*(1E6/PEN1s_singleCell.iloc[:,i].sum())
# /var/folders/kf/mfw6jp8n1j9596qy__gdvty00000gn/T/ipykernel_70607/3279156493.py:3: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value 'gene_id
# ERCC-00002      68206.169289
# ERCC-00003       4215.304799
# ERCC-00004      33722.438392
# ERCC-00009         42.294028
# ERCC-00012          0.000000
#                     ...
# LexA-p65            0.000000
# mCD8-GFP            0.000000
# myr-GFP-p10      9036.824000
# nls-tdTomato        0.000000
# unc84-2xEGFP        0.000000
# Name: 62862_CB_facs_direct_Plate_1-Q8_C07_Plate_389_Q8, Length: 17713, dtype: float64' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   PEN1s_singleCell.iloc[:,i] = PEN1s_singleCell.iloc[:,i]*(1E6/PEN1s_singleCell.iloc[:,i].sum())
# /var/folders/kf/mfw6jp8n1j9596qy__gdvty00000gn/T/ipykernel_70607/3279156493.py:3: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value 'gene_id
# ERCC-00002      66607.842735
# ERCC-00003       4114.255227
# ERCC-00004      19904.376911
# ERCC-00009       6453.532514
# ERCC-00012          0.000000
#                     ...
# LexA-p65            0.000000
# mCD8-GFP            0.000000
# myr-GFP-p10        10.259988
# nls-tdTomato     3539.695894
# unc84-2xEGFP        0.000000
# Name: 62862_CB_facs_direct_Plate_1-Q8_E07_Plate_389_Q8, Length: 17713, dtype: float64' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   PEN1s_singleCell.iloc[:,i] = PEN1s_singleCell.iloc[:,i]*(1E6/PEN1s_singleCell.iloc[:,i].sum())
# /var/folders/kf/mfw6jp8n1j9596qy__gdvty00000gn/T/ipykernel_70607/3279156493.py:3: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value 'gene_id
# ERCC-00002      34976.728631
# ERCC-00003       1086.926228
# ERCC-00004      22429.698169
# ERCC-00009       2892.895962
# ERCC-00012          0.000000
#                     ...
# LexA-p65            0.000000
# mCD8-GFP            0.000000
# myr-GFP-p10      5462.501045
# nls-tdTomato        5.573981
# unc84-2xEGFP        0.000000
# Name: 62862_CB_facs_direct_Plate_1-Q8_F07_Plate_389_Q8, Length: 17713, dtype: float64' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   PEN1s_singleCell.iloc[:,i] = PEN1s_singleCell.iloc[:,i]*(1E6/PEN1s_singleCell.iloc[:,i].sum())
# /var/folders/kf/mfw6jp8n1j9596qy__gdvty00000gn/T/ipykernel_70607/3279156493.py:3: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value 'gene_id
# ERCC-00002      42451.826457
# ERCC-00003       2051.069866
# ERCC-00004      22354.888285
# ERCC-00009       3511.053316
# ERCC-00012          0.000000
#                     ...
# LexA-p65            0.000000
# mCD8-GFP            0.000000
# myr-GFP-p10      9540.134768
# nls-tdTomato     9262.324152
# unc84-2xEGFP        0.000000
# Name: 62862_CB_facs_direct_Plate_1-Q8_G07_Plate_389_Q8, Length: 17713, dtype: float64' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   PEN1s_singleCell.iloc[:,i] = PEN1s_singleCell.iloc[:,i]*(1E6/PEN1s_singleCell.iloc[:,i].sum())
# /var/folders/kf/mfw6jp8n1j9596qy__gdvty00000gn/T/ipykernel_70607/3279156493.py:3: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value 'gene_id
# ERCC-00002      139493.778281
# ERCC-00003       15112.415158
# ERCC-00004       55783.371041
# ERCC-00009        2916.430995
# ERCC-00012           0.000000
#                     ...
# LexA-p65             0.000000
# mCD8-GFP             0.000000
# myr-GFP-p10        565.610860
# nls-tdTomato         0.000000
# unc84-2xEGFP         0.000000
# Name: 62862_CB_facs_direct_Plate_1-Q8_H07_Plate_389_Q8, Length: 17713, dtype: float64' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   PEN1s_singleCell.iloc[:,i] = PEN1s_singleCell.iloc[:,i]*(1E6/PEN1s_singleCell.iloc[:,i].sum())
# /var/folders/kf/mfw6jp8n1j9596qy__gdvty00000gn/T/ipykernel_70607/3279156493.py:3: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value 'gene_id
# ERCC-00002      218638.134604
# ERCC-00003         375.768843
# ERCC-00004       89472.539209
# ERCC-00009         217.550383
# ERCC-00012           0.000000
#                     ...
# LexA-p65             0.000000
# mCD8-GFP             0.000000
# myr-GFP-p10        158.218460
# nls-tdTomato        19.777308
# unc84-2xEGFP         0.000000
# Name: 62862_CB_facs_direct_Plate_1-Q8_A08_Plate_389_Q8, Length: 17713, dtype: float64' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   PEN1s_singleCell.iloc[:,i] = PEN1s_singleCell.iloc[:,i]*(1E6/PEN1s_singleCell.iloc[:,i].sum())
# /var/folders/kf/mfw6jp8n1j9596qy__gdvty00000gn/T/ipykernel_70607/3279156493.py:3: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value 'gene_id
# ERCC-00002      156049.834589
# ERCC-00003       11332.441754
# ERCC-00004       65460.688393
# ERCC-00009       10223.833322
# ERCC-00012           0.000000
#                     ...
# LexA-p65             0.000000
# mCD8-GFP             0.000000
# myr-GFP-p10         17.596959
# nls-tdTomato      3712.958401
# unc84-2xEGFP         0.000000
# Name: 62862_CB_facs_direct_Plate_1-Q8_B08_Plate_389_Q8, Length: 17713, dtype: float64' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   PEN1s_singleCell.iloc[:,i] = PEN1s_singleCell.iloc[:,i]*(1E6/PEN1s_singleCell.iloc[:,i].sum())
# /var/folders/kf/mfw6jp8n1j9596qy__gdvty00000gn/T/ipykernel_70607/3279156493.py:3: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value 'gene_id
# ERCC-00002      43660.640889
# ERCC-00003       1505.804261
# ERCC-00004      16963.345959
# ERCC-00009       1390.564139
# ERCC-00012          0.000000
#                     ...
# LexA-p65            0.000000
# mCD8-GFP            0.000000
# myr-GFP-p10     17547.229243
# nls-tdTomato     6269.062637
# unc84-2xEGFP        0.000000
# Name: 62862_CB_facs_direct_Plate_1-Q8_C08_Plate_389_Q8, Length: 17713, dtype: float64' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   PEN1s_singleCell.iloc[:,i] = PEN1s_singleCell.iloc[:,i]*(1E6/PEN1s_singleCell.iloc[:,i].sum())
# /var/folders/kf/mfw6jp8n1j9596qy__gdvty00000gn/T/ipykernel_70607/3279156493.py:3: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value 'gene_id
# ERCC-00002      174794.639720
# ERCC-00003       17633.379620
# ERCC-00004       80722.065146
# ERCC-00009        8866.879695
# ERCC-00012           0.000000
#                     ...
# LexA-p65             0.000000
# mCD8-GFP             0.000000
# myr-GFP-p10        200.759540
# nls-tdTomato        66.919847
# unc84-2xEGFP         0.000000
# Name: 62862_CB_facs_direct_Plate_1-Q8_F08_Plate_389_Q8, Length: 17713, dtype: float64' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   PEN1s_singleCell.iloc[:,i] = PEN1s_singleCell.iloc[:,i]*(1E6/PEN1s_singleCell.iloc[:,i].sum())
# /var/folders/kf/mfw6jp8n1j9596qy__gdvty00000gn/T/ipykernel_70607/3279156493.py:3: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value 'gene_id
# ERCC-00002      56217.220699
# ERCC-00003       3693.550493
# ERCC-00004      35230.789314
# ERCC-00009       2580.110115
# ERCC-00012          0.000000
#                     ...
# LexA-p65            0.000000
# mCD8-GFP            0.000000
# myr-GFP-p10         7.678899
# nls-tdTomato    11963.724880
# unc84-2xEGFP        0.000000
# Name: 62862_CB_facs_direct_Plate_1-Q8_G08_Plate_389_Q8, Length: 17713, dtype: float64' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   PEN1s_singleCell.iloc[:,i] = PEN1s_singleCell.iloc[:,i]*(1E6/PEN1s_singleCell.iloc[:,i].sum())
# /var/folders/kf/mfw6jp8n1j9596qy__gdvty00000gn/T/ipykernel_70607/3279156493.py:3: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value 'gene_id
# ERCC-00002      130226.137260
# ERCC-00003        9811.333158
# ERCC-00004       66772.942414
# ERCC-00009        2481.593479
# ERCC-00012           0.000000
#                     ...
# LexA-p65             0.000000
# mCD8-GFP             0.000000
# myr-GFP-p10          0.000000
# nls-tdTomato         0.000000
# unc84-2xEGFP         0.000000
# Name: 62862_CB_facs_direct_Plate_1-Q8_H08_Plate_389_Q8, Length: 17713, dtype: float64' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   PEN1s_singleCell.iloc[:,i] = PEN1s_singleCell.iloc[:,i]*(1E6/PEN1s_singleCell.iloc[:,i].sum())
# /var/folders/kf/mfw6jp8n1j9596qy__gdvty00000gn/T/ipykernel_70607/3279156493.py:3: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value 'gene_id
# ERCC-00002      80557.443916
# ERCC-00003       6184.074911
# ERCC-00004      30087.059494
# ERCC-00009       3267.472205
# ERCC-00012          0.000000
#                     ...
# LexA-p65            0.000000
# mCD8-GFP            0.000000
# myr-GFP-p10        21.929344
# nls-tdTomato     7642.376264
# unc84-2xEGFP        0.000000
# Name: 62862_CB_facs_direct_Plate_1-Q8_A09_Plate_389_Q8, Length: 17713, dtype: float64' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   PEN1s_singleCell.iloc[:,i] = PEN1s_singleCell.iloc[:,i]*(1E6/PEN1s_singleCell.iloc[:,i].sum())
# /var/folders/kf/mfw6jp8n1j9596qy__gdvty00000gn/T/ipykernel_70607/3279156493.py:3: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value 'gene_id
# ERCC-00002      111730.220767
# ERCC-00003        4211.999577
# ERCC-00004       46899.757051
# ERCC-00009        8714.481884
# ERCC-00012          13.203760
#                     ...
# LexA-p65             0.000000
# mCD8-GFP             0.000000
# myr-GFP-p10         79.222563
# nls-tdTomato        52.815042
# unc84-2xEGFP         0.000000
# Name: 62862_CB_facs_direct_Plate_1-Q8_B09_Plate_389_Q8, Length: 17713, dtype: float64' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   PEN1s_singleCell.iloc[:,i] = PEN1s_singleCell.iloc[:,i]*(1E6/PEN1s_singleCell.iloc[:,i].sum())
# /var/folders/kf/mfw6jp8n1j9596qy__gdvty00000gn/T/ipykernel_70607/3279156493.py:3: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value 'gene_id
# ERCC-00002      44578.163691
# ERCC-00003       2770.209791
# ERCC-00004      30975.388254
# ERCC-00009        816.689207
# ERCC-00012          6.533514
#                     ...
# LexA-p65            0.000000
# mCD8-GFP            0.000000
# myr-GFP-p10      7317.535297
# nls-tdTomato    11022.037542
# unc84-2xEGFP        0.000000
# Name: 62862_CB_facs_direct_Plate_1-Q8_G09_Plate_389_Q8, Length: 17713, dtype: float64' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   PEN1s_singleCell.iloc[:,i] = PEN1s_singleCell.iloc[:,i]*(1E6/PEN1s_singleCell.iloc[:,i].sum())
# /var/folders/kf/mfw6jp8n1j9596qy__gdvty00000gn/T/ipykernel_70607/3279156493.py:3: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value 'gene_id
# ERCC-00002      26996.589097
# ERCC-00003        766.948554
# ERCC-00004      13643.611117
# ERCC-00009        657.961128
# ERCC-00012          0.000000
#                     ...
# LexA-p65            0.000000
# mCD8-GFP            0.000000
# myr-GFP-p10     12650.614568
# nls-tdTomato     6224.393001
# unc84-2xEGFP        0.000000
# Name: 62862_CB_facs_direct_Plate_1-Q8_H09_Plate_389_Q8, Length: 17713, dtype: float64' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   PEN1s_singleCell.iloc[:,i] = PEN1s_singleCell.iloc[:,i]*(1E6/PEN1s_singleCell.iloc[:,i].sum())
# /var/folders/kf/mfw6jp8n1j9596qy__gdvty00000gn/T/ipykernel_70607/3279156493.py:3: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value 'gene_id
# ERCC-00002      55643.780935
# ERCC-00003       2817.719501
# ERCC-00004      17894.990515
# ERCC-00009       1872.300458
# ERCC-00012          0.000000
#                     ...
# LexA-p65            0.000000
# mCD8-GFP            0.000000
# myr-GFP-p10         0.000000
# nls-tdTomato       24.716838
# unc84-2xEGFP        0.000000
# Name: 62862_CB_facs_direct_Plate_1-Q8_A10_Plate_389_Q8, Length: 17713, dtype: float64' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   PEN1s_singleCell.iloc[:,i] = PEN1s_singleCell.iloc[:,i]*(1E6/PEN1s_singleCell.iloc[:,i].sum())
# /var/folders/kf/mfw6jp8n1j9596qy__gdvty00000gn/T/ipykernel_70607/3279156493.py:3: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value 'gene_id
# ERCC-00002      36594.101060
# ERCC-00003       1047.229602
# ERCC-00004      15232.430570
# ERCC-00009       4012.113409
# ERCC-00012          0.000000
#                     ...
# LexA-p65            0.000000
# mCD8-GFP            0.000000
# myr-GFP-p10     20105.901660
# nls-tdTomato    11945.670998
# unc84-2xEGFP        4.533461
# Name: 62862_CB_facs_direct_Plate_1-Q8_B10_Plate_389_Q8, Length: 17713, dtype: float64' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   PEN1s_singleCell.iloc[:,i] = PEN1s_singleCell.iloc[:,i]*(1E6/PEN1s_singleCell.iloc[:,i].sum())
# /var/folders/kf/mfw6jp8n1j9596qy__gdvty00000gn/T/ipykernel_70607/3279156493.py:3: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value 'gene_id
# ERCC-00002      75545.306880
# ERCC-00003       5931.662606
# ERCC-00004      35343.427312
# ERCC-00009       1609.815524
# ERCC-00012          0.000000
#                     ...
# LexA-p65            0.000000
# mCD8-GFP            0.000000
# myr-GFP-p10         0.000000
# nls-tdTomato       29.005685
# unc84-2xEGFP        0.000000
# Name: 62862_CB_facs_direct_Plate_1-Q8_C10_Plate_389_Q8, Length: 17713, dtype: float64' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
# ...
# ERCC-00002      51115.772266
# ERCC-00003       5078.521760
# ERCC-00004      20638.631624
# ERCC-00009       3576.000529
# ERCC-00012          0.000000
#                     ...
# LexA-p65            0.000000
# mCD8-GFP            0.000000
# myr-GFP-p10      8269.876853
# nls-tdTomato       30.050425
# unc84-2xEGFP        0.000000
# Name: 02232_CB_facs_direct_Plate_1-Q8_D09_Plate_393_Q8, Length: 17713, dtype: float64' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   PEN2s_singleCell.iloc[:,i] = PEN2s_singleCell.iloc[:,i]*(1E6/PEN2s_singleCell.iloc[:,i].sum())
# /var/folders/kf/mfw6jp8n1j9596qy__gdvty00000gn/T/ipykernel_70607/3279156493.py:7: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value 'gene_id
# ERCC-00002      53671.897071
# ERCC-00003       4955.875945
# ERCC-00004      29744.832242
# ERCC-00009        742.184320
# ERCC-00012          0.000000
#                     ...
# LexA-p65            0.000000
# mCD8-GFP            0.000000
# myr-GFP-p10      8566.243542
# nls-tdTomato        0.000000
# unc84-2xEGFP        0.000000
# Name: 02232_CB_facs_direct_Plate_1-Q8_E09_Plate_393_Q8, Length: 17713, dtype: float64' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   PEN2s_singleCell.iloc[:,i] = PEN2s_singleCell.iloc[:,i]*(1E6/PEN2s_singleCell.iloc[:,i].sum())
# /var/folders/kf/mfw6jp8n1j9596qy__gdvty00000gn/T/ipykernel_70607/3279156493.py:7: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value 'gene_id
# ERCC-00002      170198.102556
# ERCC-00003       15645.849524
# ERCC-00004       74387.436397
# ERCC-00009       11716.057891
# ERCC-00012           0.000000
#                     ...
# LexA-p65             0.000000
# mCD8-GFP             0.000000
# myr-GFP-p10         29.326803
# nls-tdTomato         0.000000
# unc84-2xEGFP         0.000000
# Name: 02232_CB_facs_direct_Plate_1-Q8_G09_Plate_393_Q8, Length: 17713, dtype: float64' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   PEN2s_singleCell.iloc[:,i] = PEN2s_singleCell.iloc[:,i]*(1E6/PEN2s_singleCell.iloc[:,i].sum())
# /var/folders/kf/mfw6jp8n1j9596qy__gdvty00000gn/T/ipykernel_70607/3279156493.py:7: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value 'gene_id
# ERCC-00002      125742.824630
# ERCC-00003        5158.679985
# ERCC-00004       69098.495385
# ERCC-00009       18245.037299
# ERCC-00012           0.000000
#                     ...
# LexA-p65             0.000000
# mCD8-GFP             0.000000
# myr-GFP-p10         25.287647
# nls-tdTomato        12.643823
# unc84-2xEGFP         0.000000
# Name: 02232_CB_facs_direct_Plate_1-Q8_H09_Plate_393_Q8, Length: 17713, dtype: float64' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   PEN2s_singleCell.iloc[:,i] = PEN2s_singleCell.iloc[:,i]*(1E6/PEN2s_singleCell.iloc[:,i].sum())
# /var/folders/kf/mfw6jp8n1j9596qy__gdvty00000gn/T/ipykernel_70607/3279156493.py:7: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value 'gene_id
# ERCC-00002      85160.115092
# ERCC-00003       7400.277381
# ERCC-00004      42217.806206
# ERCC-00009       6168.622824
# ERCC-00012          0.000000
#                     ...
# LexA-p65            0.000000
# mCD8-GFP            0.000000
# myr-GFP-p10        10.350038
# nls-tdTomato        0.000000
# unc84-2xEGFP        0.000000
# Name: 02232_CB_facs_direct_Plate_1-Q8_B10_Plate_393_Q8, Length: 17713, dtype: float64' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   PEN2s_singleCell.iloc[:,i] = PEN2s_singleCell.iloc[:,i]*(1E6/PEN2s_singleCell.iloc[:,i].sum())
# /var/folders/kf/mfw6jp8n1j9596qy__gdvty00000gn/T/ipykernel_70607/3279156493.py:7: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value 'gene_id
# ERCC-00002      33403.346251
# ERCC-00003       1280.517955
# ERCC-00004      22026.599274
# ERCC-00009       1001.593252
# ERCC-00012          0.000000
#                     ...
# LexA-p65            0.000000
# mCD8-GFP            0.000000
# myr-GFP-p10        38.035187
# nls-tdTomato        0.000000
# unc84-2xEGFP        0.000000
# Name: 02232_CB_facs_direct_Plate_1-Q8_C10_Plate_393_Q8, Length: 17713, dtype: float64' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   PEN2s_singleCell.iloc[:,i] = PEN2s_singleCell.iloc[:,i]*(1E6/PEN2s_singleCell.iloc[:,i].sum())
# /var/folders/kf/mfw6jp8n1j9596qy__gdvty00000gn/T/ipykernel_70607/3279156493.py:7: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value 'gene_id
# ERCC-00002      170259.489983
# ERCC-00003       10203.319440
# ERCC-00004      105857.571819
# ERCC-00009       11069.779949
# ERCC-00012           0.000000
#                     ...
# LexA-p65             0.000000
# mCD8-GFP             0.000000
# myr-GFP-p10          0.000000
# nls-tdTomato        14.938974
# unc84-2xEGFP         0.000000
# Name: 02232_CB_facs_direct_Plate_1-Q8_D10_Plate_393_Q8, Length: 17713, dtype: float64' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   PEN2s_singleCell.iloc[:,i] = PEN2s_singleCell.iloc[:,i]*(1E6/PEN2s_singleCell.iloc[:,i].sum())
# /var/folders/kf/mfw6jp8n1j9596qy__gdvty00000gn/T/ipykernel_70607/3279156493.py:7: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value 'gene_id
# ERCC-00002      102517.625734
# ERCC-00003        6885.512176
# ERCC-00004       58356.186956
# ERCC-00009       11899.577453
# ERCC-00012           0.000000
#                     ...
# LexA-p65             0.000000
# mCD8-GFP             0.000000
# myr-GFP-p10         23.540213
# nls-tdTomato         0.000000
# unc84-2xEGFP         0.000000
# Name: 02232_CB_facs_direct_Plate_1-Q8_E10_Plate_393_Q8, Length: 17713, dtype: float64' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   PEN2s_singleCell.iloc[:,i] = PEN2s_singleCell.iloc[:,i]*(1E6/PEN2s_singleCell.iloc[:,i].sum())
# /var/folders/kf/mfw6jp8n1j9596qy__gdvty00000gn/T/ipykernel_70607/3279156493.py:7: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value 'gene_id
# ERCC-00002      45570.698467
# ERCC-00003       1351.562772
# ERCC-00004      16748.948302
# ERCC-00009       2898.689288
# ERCC-00012          0.000000
#                     ...
# LexA-p65            0.000000
# mCD8-GFP            0.000000
# myr-GFP-p10         4.345861
# nls-tdTomato        4.345861
# unc84-2xEGFP        0.000000
# Name: 02232_CB_facs_direct_Plate_1-Q8_F10_Plate_393_Q8, Length: 17713, dtype: float64' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   PEN2s_singleCell.iloc[:,i] = PEN2s_singleCell.iloc[:,i]*(1E6/PEN2s_singleCell.iloc[:,i].sum())
# /var/folders/kf/mfw6jp8n1j9596qy__gdvty00000gn/T/ipykernel_70607/3279156493.py:7: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value 'gene_id
# ERCC-00002      137762.812819
# ERCC-00003        9534.604614
# ERCC-00004       73265.324265
# ERCC-00009        5734.097880
# ERCC-00012           0.000000
#                     ...
# LexA-p65             0.000000
# mCD8-GFP             0.000000
# myr-GFP-p10          0.000000
# nls-tdTomato        11.112593
# unc84-2xEGFP         0.000000
# Name: 02232_CB_facs_direct_Plate_1-Q8_G10_Plate_393_Q8, Length: 17713, dtype: float64' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   PEN2s_singleCell.iloc[:,i] = PEN2s_singleCell.iloc[:,i]*(1E6/PEN2s_singleCell.iloc[:,i].sum())
# /var/folders/kf/mfw6jp8n1j9596qy__gdvty00000gn/T/ipykernel_70607/3279156493.py:7: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value 'gene_id
# ERCC-00002      45063.488699
# ERCC-00003        722.557275
# ERCC-00004      21951.290006
# ERCC-00009       2509.682267
# ERCC-00012          0.000000
#                     ...
# LexA-p65            0.000000
# mCD8-GFP            0.000000
# myr-GFP-p10     10785.371587
# nls-tdTomato     5539.605773
# unc84-2xEGFP        0.000000
# Name: 02232_CB_facs_direct_Plate_1-Q8_H10_Plate_393_Q8, Length: 17713, dtype: float64' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   PEN2s_singleCell.iloc[:,i] = PEN2s_singleCell.iloc[:,i]*(1E6/PEN2s_singleCell.iloc[:,i].sum())
# /var/folders/kf/mfw6jp8n1j9596qy__gdvty00000gn/T/ipykernel_70607/3279156493.py:7: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value 'gene_id
# ERCC-00002      55811.577952
# ERCC-00003       2318.878015
# ERCC-00004      24779.706589
# ERCC-00009       1673.114517
# ERCC-00012          0.000000
#                     ...
# LexA-p65            0.000000
# mCD8-GFP            0.000000
# myr-GFP-p10       522.481376
# nls-tdTomato        5.870577
# unc84-2xEGFP        0.000000
# Name: 02232_CB_facs_direct_Plate_1-Q8_B11_Plate_393_Q8, Length: 17713, dtype: float64' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   PEN2s_singleCell.iloc[:,i] = PEN2s_singleCell.iloc[:,i]*(1E6/PEN2s_singleCell.iloc[:,i].sum())
# /var/folders/kf/mfw6jp8n1j9596qy__gdvty00000gn/T/ipykernel_70607/3279156493.py:7: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value 'gene_id
# ERCC-00002      66412.088363
# ERCC-00003       1281.103720
# ERCC-00004      37193.068900
# ERCC-00009       4836.987764
# ERCC-00012          0.000000
#                     ...
# LexA-p65            0.000000
# mCD8-GFP            0.000000
# myr-GFP-p10         0.000000
# nls-tdTomato        0.000000
# unc84-2xEGFP        0.000000
# Name: 02232_CB_facs_direct_Plate_1-Q8_C11_Plate_393_Q8, Length: 17713, dtype: float64' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   PEN2s_singleCell.iloc[:,i] = PEN2s_singleCell.iloc[:,i]*(1E6/PEN2s_singleCell.iloc[:,i].sum())
# /var/folders/kf/mfw6jp8n1j9596qy__gdvty00000gn/T/ipykernel_70607/3279156493.py:7: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value 'gene_id
# ERCC-00002      60378.956554
# ERCC-00003       4568.524662
# ERCC-00004      31370.108246
# ERCC-00009         12.832934
# ERCC-00012          0.000000
#                     ...
# LexA-p65            0.000000
# mCD8-GFP            0.000000
# myr-GFP-p10      8572.400208
# nls-tdTomato      988.135952
# unc84-2xEGFP        6.416467
# Name: 02232_CB_facs_direct_Plate_1-Q8_E11_Plate_393_Q8, Length: 17713, dtype: float64' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   PEN2s_singleCell.iloc[:,i] = PEN2s_singleCell.iloc[:,i]*(1E6/PEN2s_singleCell.iloc[:,i].sum())
# /var/folders/kf/mfw6jp8n1j9596qy__gdvty00000gn/T/ipykernel_70607/3279156493.py:7: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value 'gene_id
# ERCC-00002      58344.225535
# ERCC-00003       1145.180051
# ERCC-00004      30512.153298
# ERCC-00009       3015.840658
# ERCC-00012          0.000000
#                     ...
# LexA-p65            0.000000
# mCD8-GFP            0.000000
# myr-GFP-p10      6205.556821
# nls-tdTomato        0.000000
# unc84-2xEGFP        0.000000
# Name: 02232_CB_facs_direct_Plate_1-Q8_F11_Plate_393_Q8, Length: 17713, dtype: float64' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   PEN2s_singleCell.iloc[:,i] = PEN2s_singleCell.iloc[:,i]*(1E6/PEN2s_singleCell.iloc[:,i].sum())
# /var/folders/kf/mfw6jp8n1j9596qy__gdvty00000gn/T/ipykernel_70607/3279156493.py:7: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value 'gene_id
# ERCC-00002      43516.710592
# ERCC-00003       2578.605889
# ERCC-00004      24809.778564
# ERCC-00009          8.755877
# ERCC-00012          0.000000
#                     ...
# LexA-p65            0.000000
# mCD8-GFP            0.000000
# myr-GFP-p10         4.377939
# nls-tdTomato        0.000000
# unc84-2xEGFP        0.000000
# Name: 02232_CB_facs_direct_Plate_1-Q8_G11_Plate_393_Q8, Length: 17713, dtype: float64' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   PEN2s_singleCell.iloc[:,i] = PEN2s_singleCell.iloc[:,i]*(1E6/PEN2s_singleCell.iloc[:,i].sum())
# /var/folders/kf/mfw6jp8n1j9596qy__gdvty00000gn/T/ipykernel_70607/3279156493.py:7: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value 'gene_id
# ERCC-00002      181339.558024
# ERCC-00003        5844.166908
# ERCC-00004       72805.029732
# ERCC-00009       12863.982553
# ERCC-00012           0.000000
#                     ...
# LexA-p65             0.000000
# mCD8-GFP             0.000000
# myr-GFP-p10         17.038387
# nls-tdTomato         0.000000
# unc84-2xEGFP         0.000000
# Name: 02232_CB_facs_direct_Plate_1-Q8_H11_Plate_393_Q8, Length: 17713, dtype: float64' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   PEN2s_singleCell.iloc[:,i] = PEN2s_singleCell.iloc[:,i]*(1E6/PEN2s_singleCell.iloc[:,i].sum())
# /var/folders/kf/mfw6jp8n1j9596qy__gdvty00000gn/T/ipykernel_70607/3279156493.py:7: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value 'gene_id
# ERCC-00002      76358.942767
# ERCC-00003       3168.177418
# ERCC-00004      33603.215113
# ERCC-00009       4202.235325
# ERCC-00012          0.000000
#                     ...
# LexA-p65            0.000000
# mCD8-GFP            0.000000
# myr-GFP-p10         7.333744
# nls-tdTomato        0.000000
# unc84-2xEGFP        0.000000
# Name: 02232_CB_facs_direct_Plate_1-Q8_B12_Plate_393_Q8, Length: 17713, dtype: float64' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   PEN2s_singleCell.iloc[:,i] = PEN2s_singleCell.iloc[:,i]*(1E6/PEN2s_singleCell.iloc[:,i].sum())
# /var/folders/kf/mfw6jp8n1j9596qy__gdvty00000gn/T/ipykernel_70607/3279156493.py:7: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value 'gene_id
# ERCC-00002      98300.523641
# ERCC-00003       3693.768587
# ERCC-00004      45842.153527
# ERCC-00009       9272.987496
# ERCC-00012          0.000000
#                     ...
# LexA-p65            0.000000
# mCD8-GFP            0.000000
# myr-GFP-p10         8.570229
# nls-tdTomato        0.000000
# unc84-2xEGFP        0.000000
# Name: 02232_CB_facs_direct_Plate_1-Q8_C12_Plate_393_Q8, Length: 17713, dtype: float64' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   PEN2s_singleCell.iloc[:,i] = PEN2s_singleCell.iloc[:,i]*(1E6/PEN2s_singleCell.iloc[:,i].sum())
# /var/folders/kf/mfw6jp8n1j9596qy__gdvty00000gn/T/ipykernel_70607/3279156493.py:7: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value 'gene_id
# ERCC-00002      101186.114916
# ERCC-00003        4194.408164
# ERCC-00004       55121.956399
# ERCC-00009        9089.654147
# ERCC-00012           0.000000
#                     ...
# LexA-p65             0.000000
# mCD8-GFP             0.000000
# myr-GFP-p10       2463.551124
# nls-tdTomato      4364.308241
# unc84-2xEGFP         0.000000
# Name: 02232_CB_facs_direct_Plate_1-Q8_D12_Plate_393_Q8, Length: 17713, dtype: float64' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   PEN2s_singleCell.iloc[:,i] = PEN2s_singleCell.iloc[:,i]*(1E6/PEN2s_singleCell.iloc[:,i].sum())

# %% [markdown]
# #### Find the average counts across samples for the single cell data

# %%
PEN1Mean = PEN1s_singleCell.mean(axis=1)
PEN2Mean = PEN2s_singleCell.mean(axis=1)
wholeBrainMean = wholeBrain_singleCell.mean(axis=1)

singleCellSeqMean = pd.concat([PEN1Mean, PEN2Mean,wholeBrainMean], axis=1, join='inner')
singleCellSeqMean = singleCellSeqMean.rename(columns={0: "P-EN1", 1: "P-EN2", 2: "wholeBrain"})

# %% [markdown]
# ## Plot the data

# %%
def pltHtMap(genes,counts,cLabel,maxCts):

    lookAtGenes = counts.loc[genes['gene_id'].values]
    pc = plt.pcolor(np.log10(lookAtGenes.values+1),vmin=0,vmax=maxCts)
    plt.yticks(np.arange(0.5, len(genes), 1), genes["name"],fontsize = 6)
    plt.xticks(np.arange(0.5, len(lookAtGenes.columns)+0.5, 1), lookAtGenes.columns,rotation = 90,fontsize = 6)
    cbar = plt.colorbar(pc)
    cbar.set_label('log10(' + cLabel + '+1)', rotation=270,fontsize = 6)
    cbar.ax.tick_params(labelsize=6)

# %% [markdown]
# #### Figure 2

# %%
genes2plt = transmitters.iloc[0:17,]

fig = plt.figure(figsize=[4,2])
gs = fig.add_gridspec(1,4)
rcParams['svg.fonttype'] = 'none'

ax1 = fig.add_subplot(gs[0, 0:2])
plt1 = pltHtMap(genes2plt,bulkSeq[['E-PG_l1r1','E-PG_l1r2','E-PG_l2r1','E-PG_l2r2',
                   'P-EG_r1','P-EG_r2',
                   'D7_l1r1','D7_l1r2','D7_l2r1','D7_l2r2',
                   'wholebrain_1', 'wholebrain_2']],'FPKM',3)
ax1.axvline(x=4, color = 'r',linewidth=0.5)
ax1.axvline(x=6, color = 'r',linewidth=0.5)
ax1.axvline(x=10, color = 'r',linewidth=0.5)
ax1.set_aspect('equal')

ax2 = fig.add_subplot(gs[0,2])
plt2 = pltHtMap(genes2plt,lowCellSeqMean[['R4d','wholeBrain']],'CPM',4)
ax2.axvline(x=1, color = 'r',linewidth=0.5)
ax2.set_aspect('equal')
ax2.tick_params(axis='y',labelleft=False) 

ax3 = fig.add_subplot(gs[0,3])
plt3 = pltHtMap(genes2plt,singleCellSeqMean,'CPM',4)
ax3.axvline(x=1, color = 'r',linewidth=0.5)
ax3.axvline(x=2, color = 'r',linewidth=0.5)
ax3.set_aspect('equal')
ax3.tick_params(axis='y',labelleft=False) 

plt.show()
    
# fig.savefig("plots//transmitters.svg")

# %%
genes2plt = retrotransmitters

fig = plt.figure()
gs = fig.add_gridspec(1,4)
rcParams['svg.fonttype'] = 'none'

ax1 = fig.add_subplot(gs[0, 0:2])
plt1 = pltHtMap(genes2plt,bulkSeq[['E-PG_l1r1','E-PG_l1r2','E-PG_l2r1','E-PG_l2r2',
                   'P-EG_r1','P-EG_r2',
                   'D7_l1r1','D7_l1r2','D7_l2r1','D7_l2r2',
                   'wholebrain_1', 'wholebrain_2']],'FPKM',3)
ax1.axvline(x=4, color = 'r',linewidth=0.5)
ax1.axvline(x=6, color = 'r',linewidth=0.5)
ax1.axvline(x=10, color = 'r',linewidth=0.5)
ax1.set_aspect('equal')

ax2 = fig.add_subplot(gs[0,2], sharey=ax1)
plt2 = pltHtMap(genes2plt,lowCellSeqMean[['R4d','wholeBrain']],'CPM',4)
ax2.axvline(x=1, color = 'r',linewidth=0.5)
ax2.set_aspect('equal')
ax2.tick_params(axis='y',labelleft=False) 

ax3 = fig.add_subplot(gs[0,3])
plt3 = pltHtMap(genes2plt,singleCellSeqMean,'CPM',4)
ax3.axvline(x=1, color = 'r',linewidth=0.5)
ax3.axvline(x=2, color = 'r',linewidth=0.5)
ax3.set_aspect('equal')
ax3.tick_params(axis='y',labelleft=False) 

plt.show()

# %% [markdown]
# #### Figure 3

# %%
genes2plt = receptors

fig = plt.figure(figsize=[2,4])
rcParams['svg.fonttype'] = 'none'

ax1 = fig.add_subplot()
plt1 = pltHtMap(genes2plt,
                bulkSeq[['E-PG_l1r1','E-PG_l1r2','E-PG_l2r1','E-PG_l2r2',
                         'wholebrain_1', 'wholebrain_2']],
                'FPKM',3)
ax1.axvline(x=4, color = 'r',linewidth=0.5)
ax1.set_aspect('equal')

fig.savefig("plots//EPG_receptors.svg")

# %% [markdown]
# #### Figure 5

# %%
genes2plt = VgatedChannels

fig = plt.figure(figsize=[2,4])
rcParams['svg.fonttype'] = 'none'

ax1 = fig.add_subplot()
plt1 = pltHtMap(genes2plt,
                bulkSeq[['E-PG_l1r1','E-PG_l1r2','E-PG_l2r1','E-PG_l2r2',
                         'wholebrain_1', 'wholebrain_2']],
                'FPKM',3)
ax1.axvline(x=4, color = 'r',linewidth=0.5)
ax1.set_aspect('equal')

fig.savefig("plots//EPG_VgatedChannels.svg")

# %% [markdown]
# #### Figure 6

# %%
genes2plt = receptors

fig = plt.figure(figsize=[4,4])
rcParams['svg.fonttype'] = 'none'

ax1 = fig.add_subplot()
plt1 = pltHtMap(genes2plt,
                lowCellSeq[['ring_r1','ring_r2','ring_r3','ring_r4','ring_r5','ring_r6','ring_r7',
                      'wholebrain_r1','wholebrain_r2','wholebrain_r3','wholebrain_r4',
                      'wholebrain_r5','wholebrain_r6','wholebrain_r7','wholebrain_r8']],
                'CPM',4)
ax1.axvline(x=7, color = 'r',linewidth=0.5)
ax1.set_aspect('equal')

fig.savefig("plots//ring_receptors.svg")

# %% [markdown]
# ## Look at the most differentially expressed genes

# %% [markdown]
# ### Plot the p values
# 1. Put all the p values into one matrix
# 2. Determine if the sample counts are greater than or less than the bulk counts
# 3. Plot the log 10 of the p values, flipping the sign of those where the counts are higher

# %%
def names4GenesPVals(dge_table,genesOfInt):
    dge_genes = dge_table['Unnamed: 0']
    dge_pvals = dge_table['PValue']

    geneNames = []
    genePs = []
    for i,gene in enumerate(dge_genes):
        for j,intGene in enumerate(genesOfInt['gene_id']):
            if gene == intGene:
                geneNames.append(genesOfInt['name'][j])
                genePs.append(dge_pvals[i])

    d = {'gene_names': geneNames, 'PValue': genePs}
    return pd.DataFrame(data=d)

# %% [markdown]
# #### Load the differential gene expression tables

# %%
# bulk
dge_table_EPG_bulk = pd.read_csv('./dge/dge_table_EPG_wholebrain.csv',delimiter=',')
dge_table_PEG_bulk = pd.read_csv('./dge/dge_table_PEG_wholebrain.csv',delimiter=',')
dge_table_D7_bulk = pd.read_csv('./dge/dge_table_D7_wholebrain.csv',delimiter=',')
dge_table_PEN2_bulk = pd.read_csv('./dge/dge_table_PEN2_wholebrain.csv',delimiter=',')

# low cell
dge_table_ring_lowCell = pd.read_csv('./dge/dge_table_ring_wholebrain.csv',delimiter=',')
dge_table_PEN2_lowCell = pd.read_csv('./dge/dge_table_PEN2_wholebrain.csv',delimiter=',')

# %% [markdown]
# #### Extract the p-values for the genes of interest and convert to a data frame

# %%
# Load the genes of interest
genesOfInt = pd.concat([glia,transmitters,receptors,VgatedChannels,innexins,neuropeptides,GPCRs,NOreceptors, retrotransmitters]).reset_index()

# bulk
EPG_PVals_bulk = names4GenesPVals(dge_table_EPG_bulk,genesOfInt)
PEG_PVals_bulk = names4GenesPVals(dge_table_PEG_bulk,genesOfInt)
D7_PVals_bulk = names4GenesPVals(dge_table_D7_bulk,genesOfInt)
PEN2_PVals_bulk = names4GenesPVals(dge_table_PEN2_bulk,genesOfInt)

combPVals_bulk = pd.DataFrame({'gene_names':EPG_PVals_bulk['gene_names']})
combPVals_bulk = pd.merge(combPVals_bulk,EPG_PVals_bulk,on='gene_names')
combPVals_bulk = combPVals_bulk.rename(columns = {"PValue":"PValue - EPG"})
combPVals_bulk = pd.merge(combPVals_bulk,PEG_PVals_bulk,on='gene_names')
combPVals_bulk = combPVals_bulk.rename(columns = {"PValue":"PValue - PEG"})
combPVals_bulk = pd.merge(combPVals_bulk,D7_PVals_bulk,on='gene_names')
combPVals_bulk = combPVals_bulk.rename(columns = {"PValue":"PValue - D7"})
combPVals_bulk = pd.merge(combPVals_bulk,PEN2_PVals_bulk,on='gene_names')
combPVals_bulk = combPVals_bulk.rename(columns = {"PValue":"PValue - PEN2"})

# low cell
ring_PVals_lowCell = names4GenesPVals(dge_table_ring_lowCell,genesOfInt)
PEN2_PVals_lowCell = names4GenesPVals(dge_table_PEN2_lowCell,genesOfInt)

combPVals_lowCell = pd.DataFrame({'gene_names':PEN2_PVals_lowCell['gene_names']})
combPVals_lowCell = pd.merge(combPVals_lowCell,PEN2_PVals_lowCell,on='gene_names')
combPVals_lowCell = combPVals_lowCell.rename(columns = {"PValue":"PValue - PEN2_lc"})
combPVals_lowCell = pd.merge(combPVals_lowCell,ring_PVals_lowCell,on='gene_names')
combPVals_lowCell = combPVals_lowCell.rename(columns = {"PValue":"PValue - R4m_lc"})

# %% [markdown]
# #### Find the mean expression values across samples

# %%
# bulk
EPGMeanVals = bulkSeq[[nm for nm in bulkSeq.columns if 'E-PG' in nm]].mean(axis=1)
PEGMeanVals = bulkSeq[[nm for nm in bulkSeq.columns if 'P-EG' in nm]].mean(axis=1)
D7MeanVals = bulkSeq[[nm for nm in bulkSeq.columns if 'D7' in nm]].mean(axis=1)
PEN2MeanVals = bulkSeq[[nm for nm in bulkSeq.columns if 'P-EN2' in nm]].mean(axis=1)
WBMeanVals = bulkSeq[[nm for nm in bulkSeq.columns if 'wholebrain' in nm]].mean(axis=1)
ctDiffsBulk = pd.DataFrame({'EPGDiff':(EPGMeanVals-WBMeanVals),
                            'PEGDiff':(PEGMeanVals-WBMeanVals),
                            'D7Diff':(D7MeanVals-WBMeanVals),
                            'PEN2Diff':(PEN2MeanVals-WBMeanVals),
                           })
ctDiffsBulk[ctDiffsBulk >= 0] = 0
ctDiffsBulk[ctDiffsBulk < 0] = 1
ctDiffsBulk[ctDiffsBulk == 0] = -1


# low cell
PEN2MeanVals_lc = lowCellSeq[[nm for nm in lowCellSeq.columns if 'P-EN2' in nm]].mean(axis=1)
R4mMeanVals_lc = lowCellSeq[[nm for nm in lowCellSeq.columns if 'ring' in nm]].mean(axis=1)
WBMeanVals_lc = lowCellSeq[[nm for nm in lowCellSeq.columns if 'wholebrain' in nm]].mean(axis=1)
ctDiffsLowCell = pd.DataFrame({'R4mDiff_lc':(R4mMeanVals_lc-WBMeanVals_lc),
                        'PEN2Diff_lc':(PEN2MeanVals_lc-WBMeanVals_lc)
                       })
ctDiffsLowCell[ctDiffsLowCell >= 0] = 0
ctDiffsLowCell[ctDiffsLowCell < 0] = 1
ctDiffsLowCell[ctDiffsLowCell == 0] = -1

# %% [markdown]
# ##### Specify the genes to consider

# %%
geneGps = [transmitters, neuropeptides, receptors, VgatedChannels, retrotransmitters]
geneNm = ['transmitters','neuropeptides','receptors','VgatedChannels', 'retrotransmitters']

# %% [markdown]
# #### Plot the low cell data

# %%
for i,genesToConsider in enumerate(geneGps):

    # Select those values from the p value and signed data frames
    combDat = genesToConsider.rename(columns={'name':'gene_names'})
    combDat = pd.merge(combDat,combPVals_lowCell,on='gene_names')
    combDat = pd.merge(combDat,ctDiffsLowCell.reset_index(),on='gene_id')

    # Manipulate the data for plotting
    pltDat = pd.DataFrame({'gene_names':combDat['gene_names'],
                           'PEN2 (low cell)':(np.log10(combDat['PValue - PEN2_lc'])*combDat['PEN2Diff_lc']),
                           'R4m (low cell)':(np.log10(combDat['PValue - R4m_lc'])*combDat['R4mDiff_lc']),
                          })

    # Plot the low cell data
    fig = plt.figure()
    rcParams['svg.fonttype'] = 'none'

    pc = plt.pcolor(pltDat.iloc[:,1:3],cmap='PiYG',
               norm = colors.TwoSlopeNorm(vmin=-3., vcenter=0., vmax=3))

    plt.xticks(np.arange(0.5, 2.5, 1), pltDat.columns[1:3],fontsize = 12,rotation=90)
    plt.yticks(np.arange(0.5, len(genesToConsider)), genesToConsider["name"],fontsize = 12)

    cbar = plt.colorbar(pc)
    cbar.set_label('log10(p value)', rotation=270,size=14,labelpad=14)

    plt.gcf().subplots_adjust(bottom=0.15)
    plt.gca().set_aspect('equal', adjustable='box')

    plt.show()
    
    fig.savefig("plots//" + geneNm[i] + "_PVals_lowCell.svg")

# %% [markdown]
# #### Plot the bulk data

# %%
for i,genesToConsider in enumerate(geneGps):

    # Select those values from the p value and signed data frames
    combDat = genesToConsider.rename(columns={'name':'gene_names'})
    combDat = pd.merge(combDat,combPVals_bulk,on='gene_names')
    combDat = pd.merge(combDat,ctDiffsBulk.reset_index(),on='gene_id')

    # Manipulate the data for plotting
    pltDat = pd.DataFrame({'gene_names':combDat['gene_names'],
                           'EPG (bulk)':(np.log10(combDat['PValue - EPG'])*combDat['EPGDiff']),
                           'PEG (bulk)':(np.log10(combDat['PValue - PEG'])*combDat['PEGDiff']),
                           'D7 (bulk)':(np.log10(combDat['PValue - D7'])*combDat['D7Diff']),
                           'PEN2 (bulk)':(np.log10(combDat['PValue - PEN2'])*combDat['PEN2Diff']),
                          })

    # Plot the low cell data
    fig = plt.figure()
    rcParams['svg.fonttype'] = 'none'
    pc = plt.pcolor(pltDat.iloc[:,1:5],cmap='PiYG',
                   norm = colors.TwoSlopeNorm(vmin=-3., vcenter=0., vmax=3))

    plt.xticks(np.arange(0.5, 4.5, 1), pltDat.columns[1:5],fontsize = 12,rotation=90)
    plt.yticks(np.arange(0.5, len(genesToConsider)), genesToConsider["name"],fontsize = 12)

    cbar = plt.colorbar(pc)
    cbar.set_label('log10(p value)', rotation=270,size=14,labelpad=14)

    plt.gcf().subplots_adjust(bottom=0.15)
    plt.gca().set_aspect('equal', adjustable='box')
    plt.show()

    fig.savefig("plots//" + geneNm[i] + "_PVals_bulk.svg")

# %% [markdown]
# #### Pull out relevant p-values

# %%
combPVals_lowCell['PValue - R4m_lc'].iloc[[i for i,val in enumerate(combPVals_lowCell['gene_names']) if val == 'Gad1']]
# Out:
# 319    0.003172
# Name: PValue - R4m_lc, dtype: float64

# %%
combPVals_bulk['PValue - D7'].iloc[[i for i,val in enumerate(combPVals_bulk['gene_names']) if val == 'VGlut']]
# Out:
# 3215    0.033429
# Name: PValue - D7, dtype: float64

# %%
combPVals_bulk['PValue - EPG'].iloc[[i for i,val in enumerate(combPVals_bulk['gene_names']) if val == 'GluClalpha']]
# Out:
# 3297    0.370895
# Name: PValue - EPG, dtype: float64

# %%
combPVals_bulk['PValue - EPG'].iloc[[i for i,val in enumerate(combPVals_bulk['gene_names']) if val == 'Nmdar1']]
# Out:
# 3317    0.537809
# Name: PValue - EPG, dtype: float64

# %%
combPVals_bulk['PValue - EPG'].iloc[[i for i,val in enumerate(combPVals_bulk['gene_names']) if val == 'Nmdar2']]
# Out:
# 3287    0.272425
# Name: PValue - EPG, dtype: float64

# %%
combPVals_bulk['PValue - EPG'].iloc[[i for i,val in enumerate(combPVals_bulk['gene_names']) if val == 'mAChR-B']]
# Out:
# 3202    0.008478
# Name: PValue - EPG, dtype: float64

# %%
combPVals_lowCell['PValue - R4m_lc'].iloc[[i for i,val in enumerate(combPVals_lowCell['gene_names']) if val == 'Rdl']]
# Out:
# 217    9.891596e-30
# Name: PValue - R4m_lc, dtype: float64
